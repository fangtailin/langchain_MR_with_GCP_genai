# %% [markdown]
# This notebook is based on Google Colab environment. And the demo is just for text summarization, you can change it to other scenario as needed.
#
# **Download text files that will be used**

# %%
! wget https://github.com/fangtailin/langchain_MR_with_GCP_genai/blob/main/data/large_text_named_worked.txt
! wget https://github.com/fangtailin/langchain_MR_with_GCP_genai/blob/main/data/small_text_named_muir_lake_tahoe_in_winter.txt
# Out:
# --2023-07-17 01:31:04--  https://github.com/fangtailin/langchain_MR_with_GCP_genai/blob/main/data/large_text_named_worked.txt
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86912 (85K) [text/plain]
# Saving to: ‘large_text_named_worked.txt’
#
# large_text_named_wo 100%[===================>]  84.88K  --.-KB/s    in 0.05s
#
# 2023-07-17 01:31:04 (1.67 MB/s) - ‘large_text_named_worked.txt’ saved [86912/86912]
#
# --2023-07-17 01:31:04--  https://github.com/fangtailin/langchain_MR_with_GCP_genai/blob/main/data/small_text_named_muir_lake_tahoe_in_winter.txt
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18094 (18K) [text/plain]
# Saving to: ‘small_text_named_muir_lake_tahoe_in_winter.txt’
#
# small_text_named_mu 100%[===================>]  17.67K  --.-KB/s    in 0.02s
#
# 2023-07-17 01:31:04 (736 KB/s) - ‘small_text_named_muir_lake_tahoe_in_winter.txt’ saved [18094/18094]

# %% [markdown]
# **Install relevant packages**

# %%
! pip install "unstructured[local-inference]"
! pip install layoutparser[layoutmodels,tesseract]
! pip install langchain
! pip install shapely==1.8.1
! pip install google-cloud-aiplatform --upgrade
! pip install pillow
# Out:
# Requirement already satisfied: unstructured[local-inference] in /usr/local/lib/python3.10/dist-packages (0.8.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (4.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (1.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (4.9.3)
# Requirement already satisfied: msg-parser in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (1.2.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (3.8.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (3.0.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (1.5.3)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (1.16.3)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (20221105)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (10.0.0)
# Requirement already satisfied: pypandoc in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (1.11)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (0.8.11)
# Requirement already satisfied: python-pptx in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (0.6.21)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (0.4.27)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (3.4.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (2.27.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (0.8.10)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (2.0.1)
# Requirement already satisfied: unstructured-inference==0.5.5 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]) (0.5.5)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.5.5->unstructured[local-inference]) (0.3.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.5.5->unstructured[local-inference]) (0.0.6)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.5.5->unstructured[local-inference]) (0.16.4)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.5.5->unstructured[local-inference]) (4.7.0.72)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.5.5->unstructured[local-inference]) (1.15.1)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.5.5->unstructured[local-inference]) (4.30.2)
# Requirement already satisfied: olefile>=0.46 in /usr/local/lib/python3.10/dist-packages (from msg-parser->unstructured[local-inference]) (0.46)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[local-inference]) (8.1.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[local-inference]) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[local-inference]) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[local-inference]) (4.65.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->unstructured[local-inference]) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[local-inference]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[local-inference]) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[local-inference]) (1.22.4)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[local-inference]) (2.0.12)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[local-inference]) (41.0.2)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx->unstructured[local-inference]) (3.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured[local-inference]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured[local-inference]) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured[local-inference]) (3.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]) (1.15.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->unstructured[local-inference]) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.5.5->unstructured[local-inference]) (3.12.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.5.5->unstructured[local-inference]) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.5.5->unstructured[local-inference]) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.5.5->unstructured[local-inference]) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.5.5->unstructured[local-inference]) (0.3.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference==0.5.5->unstructured[local-inference]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference==0.5.5->unstructured[local-inference]) (4.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (1.10.1)
# Requirement already satisfied: iopath in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (0.1.10)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (0.10.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (0.15.2+cu118)
# Requirement already satisfied: effdet in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (0.4.1)
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (0.3.10)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime->unstructured-inference==0.5.5->unstructured[local-inference]) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime->unstructured-inference==0.5.5->unstructured[local-inference]) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime->unstructured-inference==0.5.5->unstructured[local-inference]) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime->unstructured-inference==0.5.5->unstructured[local-inference]) (1.11.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]) (2.21)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime->unstructured-inference==0.5.5->unstructured[local-inference]) (10.0)
# Requirement already satisfied: timm>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (0.9.2)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (2.0.6)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (2.3.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (16.0.6)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (2.7.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (4.18.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime->unstructured-inference==0.5.5->unstructured[local-inference]) (1.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (3.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.5.5->unstructured[local-inference]) (3.1.0)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /usr/local/lib/python3.10/dist-packages (0.3.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (1.22.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (4.7.0.72)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (1.5.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (10.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (6.0)
# Requirement already satisfied: iopath in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (0.1.10)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (0.10.0)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (1.16.3)
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (0.3.10)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (0.15.2+cu118)
# Requirement already satisfied: effdet in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]) (0.4.1)
# Requirement already satisfied: timm>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]) (0.9.2)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]) (2.0.6)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]) (2.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]) (16.0.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from iopath->layoutparser[layoutmodels,tesseract]) (4.65.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->layoutparser[layoutmodels,tesseract]) (2.7.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->layoutparser[layoutmodels,tesseract]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->layoutparser[layoutmodels,tesseract]) (2022.7.1)
# Requirement already satisfied: pdfminer.six==20221105 in /usr/local/lib/python3.10/dist-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]) (20221105)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]) (4.18.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20221105->pdfplumber->layoutparser[layoutmodels,tesseract]) (2.0.12)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20221105->pdfplumber->layoutparser[layoutmodels,tesseract]) (41.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract->layoutparser[layoutmodels,tesseract]) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->layoutparser[layoutmodels,tesseract]) (2.27.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]) (3.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->layoutparser[layoutmodels,tesseract]) (1.16.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm>=0.9.2->effdet->layoutparser[layoutmodels,tesseract]) (0.16.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm>=0.9.2->effdet->layoutparser[layoutmodels,tesseract]) (0.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->layoutparser[layoutmodels,tesseract]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->layoutparser[layoutmodels,tesseract]) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->layoutparser[layoutmodels,tesseract]) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->layoutparser[layoutmodels,tesseract]) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber->layoutparser[layoutmodels,tesseract]) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]) (3.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm>=0.9.2->effdet->layoutparser[layoutmodels,tesseract]) (2023.6.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber->layoutparser[layoutmodels,tesseract]) (2.21)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.0.234)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.18)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.8.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.5.9)
# Requirement already satisfied: langsmith<0.0.6,>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.0.5)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.22.4)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.10.11)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.27.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2,>=1->langchain) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: shapely==1.8.1 in /usr/local/lib/python3.10/dist-packages (1.8.1)
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.10/dist-packages (1.28.0)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.11.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.22.3)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (23.1)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.8.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.10.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.10.2)
# Requirement already satisfied: shapely<2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.8.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.59.1)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.17.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.27.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.56.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.48.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.5.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.12.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.4)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (10.0.0)

# %% [markdown]
# **Import relevant libararies**

# %%
from langchain.document_loaders import UnstructuredFileLoader
from langchain.chains.summarize import load_summarize_chain
from langchain.chains.question_answering import load_qa_chain
import os
from langchain.llms import VertexAI
from langchain import PromptTemplate, LLMChain

# %% [markdown]
# **Set project ID and region information**
#
# Input your correct PROJECT_ID and region in the follow cell.

# %%
PROJECT_ID = 'XXXX' # @param {type:"string"}
os.environ['PROJECT_ID'] = PROJECT_ID
LOCATION = 'xxxx-xxxx' # @param {type:"string"}
os.environ['LOCATION_ID'] = LOCATION

# %% [markdown]
# **Load Documents**

# %%
sm_loader = UnstructuredFileLoader("/content/small_text_named_muir_lake_tahoe_in_winter.txt")
sm_doc = sm_loader.load()

lg_loader = UnstructuredFileLoader("/content/large_text_named_worked.txt")
lg_doc = lg_loader.load()

# %%
def doc_summary(docs):
    print (f'You have {len(docs)} document(s)')

    num_words = sum([len(doc.page_content.split(' ')) for doc in docs])

    print (f'You have roughly {num_words} words in your docs')
    print ()
    print (f'Preview: \n{docs[0].page_content.split(". ")[0]}')

doc_summary(sm_doc)
# Out:
# You have 1 document(s)
# You have roughly 2320 words in your docs
#
# Preview:
# {"payload":{"allShortcutsEnabled":false,"fileTree":{"data":{"items":[{"name":"large_text_named_worked.txt","path":"data/large_text_named_worked.txt","contentType":"file"},{"name":"small_text_named_muir_lake_tahoe_in_winter.txt","path":"data/small_text_named_muir_lake_tahoe_in_winter.txt","contentType":"file"},{"name":"test.txt","path":"data/test.txt","contentType":"file"}],"totalCount":3},"":{"items":[{"name":"data","path":"data","contentType":"directory"},{"name":"LICENSE","path":"LICENSE","contentType":"file"},{"name":"README.md","path":"README.md","contentType":"file"}],"totalCount":3}},"fileTreeProcessingTime":2.9682720000000002,"foldersToFetch":[],"reducedMotionEnabled":null,"repo":{"id":666981890,"defaultBranch":"main","name":"langchain_MR_with_GCP_genai","ownerLogin":"fangtailin","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"2023-07-16T08:36:54.000Z","ownerAvatar":"https://avatars.githubusercontent.com/u/38515542?v=4","public":true,"private":false,"isOrgOwned":false},"refInfo":{"name":"main","listCacheKey":"v0:1689497119.0","canEdit":false,"refType":"branch","currentOid":"211b4e147268d1e756fe4fbb77d66d60bc55d6cd"},"path":"data/small_text_named_muir_lake_tahoe_in_winter.txt","currentUser":null,"blob":{"rawLines":["The winter glory of the Sierra ! How little is known of it!
#
# Californians admire descriptions of the Swiss Alps, reading with breathless interest how ice and snow load their sublime heights, and booming avalanches sweep in glorious array through their crowded forests, while our own icy, snow-laden mountains, with their unrivaled forests, loom unnoticed along our eastern horizon

# %%
doc_summary(lg_doc)
# Out:
# You have 1 document(s)
# You have roughly 12556 words in your docs
#
# Preview:
# {"payload":{"allShortcutsEnabled":false,"fileTree":{"data":{"items":[{"name":"large_text_named_worked.txt","path":"data/large_text_named_worked.txt","contentType":"file"},{"name":"small_text_named_muir_lake_tahoe_in_winter.txt","path":"data/small_text_named_muir_lake_tahoe_in_winter.txt","contentType":"file"},{"name":"test.txt","path":"data/test.txt","contentType":"file"}],"totalCount":3},"":{"items":[{"name":"data","path":"data","contentType":"directory"},{"name":"LICENSE","path":"LICENSE","contentType":"file"},{"name":"README.md","path":"README.md","contentType":"file"}],"totalCount":3}},"fileTreeProcessingTime":4.1075859999999995,"foldersToFetch":[],"reducedMotionEnabled":null,"repo":{"id":666981890,"defaultBranch":"main","name":"langchain_MR_with_GCP_genai","ownerLogin":"fangtailin","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"2023-07-16T08:36:54.000Z","ownerAvatar":"https://avatars.githubusercontent.com/u/38515542?v=4","public":true,"private":false,"isOrgOwned":false},"refInfo":{"name":"main","listCacheKey":"v0:1689497119.0","canEdit":false,"refType":"branch","currentOid":"211b4e147268d1e756fe4fbb77d66d60bc55d6cd"},"path":"data/large_text_named_worked.txt","currentUser":null,"blob":{"rawLines":["February 2021Before college the two main things I worked on, outside of school,\r","were writing and programming

# %% [markdown]
# **Colab Authentication with GCP**

# %%
from google.colab import auth as google_auth
google_auth.authenticate_user()

# %% [markdown]
# **Load LLM**

# %%
llm = VertexAI(project=PROJECT_ID)

# %% [markdown]
# **Summarize: Stuff**

# %%
chain = load_summarize_chain(llm, chain_type="stuff", verbose=True)

# %%
chain.run(sm_doc)
# Out:
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Write a concise summary of the following:
#
#
# "{"payload":{"allShortcutsEnabled":false,"fileTree":{"data":{"items":[{"name":"large_text_named_worked.txt","path":"data/large_text_named_worked.txt","contentType":"file"},{"name":"small_text_named_muir_lake_tahoe_in_winter.txt","path":"data/small_text_named_muir_lake_tahoe_in_winter.txt","contentType":"file"},{"name":"test.txt","path":"data/test.txt","contentType":"file"}],"totalCount":3},"":{"items":[{"name":"data","path":"data","contentType":"directory"},{"name":"LICENSE","path":"LICENSE","contentType":"file"},{"name":"README.md","path":"README.md","contentType":"file"}],"totalCount":3}},"fileTreeProcessingTime":2.9682720000000002,"foldersToFetch":[],"reducedMotionEnabled":null,"repo":{"id":666981890,"defaultBranch":"main","name":"langchain_MR_with_GCP_genai","ownerLogin":"fangtailin","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"2023-07-16T08:36:54.000Z","ownerAvatar":"https://avatars.githubusercontent.com/u/38515542?v=4","public":true,"private":false,"isOrgOwned":false},"refInfo":{"name":"main","listCacheKey":"v0:1689497119.0","canEdit":false,"refType":"branch","currentOid":"211b4e147268d1e756fe4fbb77d66d60bc55d6cd"},"path":"data/small_text_named_muir_lake_tahoe_in_winter.txt","currentUser":null,"blob":{"rawLines":["The winter glory of the Sierra ! How little is known of it!
#
# Californians admire descriptions of the Swiss Alps, reading with breathless interest how ice and snow load their sublime heights, and booming avalanches sweep in glorious array through their crowded forests, while our own icy, snow-laden mountains, with their unrivaled forests, loom unnoticed along our eastern horizon. True, only mountaineers may penetrate their snow-blocked fastnesses to behold them in all their white wild grandeur, but to every healthy man and woman, and even to children, many of the subalpine valleys and lake-basins, six or seven thousand feet above the sea, remain invitingly open and approachable all winter. With a friend and his two little sons I have just returned from a week of bracing weathering around Lake Tahoe, in which we enjoyed glorious views of winter, fine rolling and sliding in the snow, swimming in the icy lake, and lusty reviving exercise on snow-shoes that kept our pulses dancing right merrily. All the weather was hearty and exhilarating, though varying almost from hour to hour: snowing, blowing, clear and cloudy, but never rigorously cold. ","","This winter has been remarkably mild, the mercury having seldom made a very near approach to zero, even during the coldest nights around the lake, while the average noonday temperature was considerably above the freezing- point.
#
# The snow lies deep on the surrounding mountains and about the shores, solid white contrasting with the dark-blue water of the lake, while the forests and canons and the upper glacial fountain hollows are well filled, assuring abundance of summer water for the lakes and streams. ","","According to the record kept by Mr. McKinney, on the west shore of the lake, eight miles above Tahoe City, at an elevation of 6,500 feet above sea-level, the amount of snow, measured as it fell, was twenty-two feet and four inches for the season up to March 20th, with four inches of rain, while an inch or two more of rain and two or three feet of snow will probably fall before the full opening of spring. Last season the snowfall, measured by the same observer, at the same station, was only nine feet and seven inches, while the season before last it was no less than forty seven feet and six inches. The fall about Yosemite Valley, according to my own observations, usually considerably exceeded this.
#
# The greater portion of the snow that loads the main summits of the range falls in small crisp flakes and broken crystals; or when accompanied by strong winds at a low temperature, the crystals, instead of being locked together in tufted flakes, are driven against each other and broken into meal and fine dust which darkens the sky like night But down in the forested region, at about the elevation of Lake Tahoe, the greater portion comes gently to the ground, light and feathery, some of the flakes in mild weather being nearly an inch in diameter, and is evenly distributed and kept from drifting to any great extent by Lake Tahoe in Winter. 121 the shelter of the woods. Every tree is loaded with the fairy bloom, bending down the branches, and hushing the singing of the elastic needles. When the storm is over and the sun shines, the dazzling snow at once begins to settle and shift and fall off the trees in miniature avalanches; then the relieved branches spring up and shake themselves dry, and the whole green forest, fed and refreshed, waves and sings again rejoicing. The snow on the ground settles also, and thaws and freezes until it becomes coarsely granulated ice, with all trace of its crystalline snow structure destroyed. This is the present condition of most of the snow on the range. From towards midnight until midday at this time of year a man may walk firmly over the surface, as if on ice, provided the preceding day has been warm and the night frosty.
#
# ","","The forested region up to an elevation of about eight thousand feet is generally clear of snow towards the end of May or middle of June; but now (March 28th) the higher canons are still heavily blocked, and the head tributaries of the rivers flow in dark tunnels beneath the icy mass. As warm summer advances, the roof of compacted snow falls in here and there, leaving magnificent arching bridges where it is strongest, over which one may safely ride a horse. All the upper streams are thus buried and bridged every winter, and are seldom completely opened to the light before the end of June or middle of July. ","","Notwithstanding twenty-two feet of snow has fallen here this season, so greatly has it been melted and compacted, the present average depth at a height of 7,500 feet does not exceed seven feet. The drifts in exposed lake hollows and along the lee sides of bald ridges above the timberline are often fifty feet or more in depth, and many of the latter are grandly adorned with overcurling cornices, beneath which pale blue light shimmers with ineffable beauty. But it is in the fountain cirques of the ancient glaciers, beneath the shadows of the highest peaks, that the heaviest and most enduring deposits are stored up. For there the lavish snowfall on the steep converging slopes is shot down in avalanches during or after' every storm, heaping snow on snow to a depth of a hundred feet, or even more at times.
#
# These treasured banks are never wholly melted, however hot the summer, but with the few lingering glaciers form perennial fountains for the highest tributaries of the rivers. ","","Few even among Californians have any fair conception of the marvelous abundance of glacier lakes hidden in the fastnesses of our mountains. The snow and some of the glaciers make a telling show, even from the distant lowlands; but not a single stream is visible, nor a hollow where one might hope to find a lake. Nevertheless, wild rivers are falling and sounding in every canon, and all their upper branches are fairly laden with lakes like orchard-trees with fruit. They nestle in rocky nooks and hollows about all the high peaks and in the larger canons, reflecting their stern, rugged beauty and giving charming animation to the bleakest and most forbidding landscapes. From the summit of Red Mountain, a day's journey to the east of Yosemite Valley, forty-two may be seen within a radius of eight or ten miles. The whole number in the Sierra can hardly be less than fifteen hundred, exclusive of the smaller gems, which are innumerable. Perhaps two-thirds of them lie on the west flank of the range, and all are restricted to the alpine and subalpine regions, those which once brightened the lower regions having long since vanished by the filling in of their basins. Lake Tahoe is king of them all, not only in size, but in the surpassing beauty of its shores and waters.
#
# It seems a kind of heaven to which the dead lakes of the lowlands had come with their best beauty spiritualized. It lies embosomed in mountains of moderate height near the northern extremity of the high portion of the Lake Tahoe in Winter. 123 range, between the main axis and a spur that puts out on the east side from near the head of the Carson River. Though it is twenty-one miles long by ten wide, and from about five hundred to sixteen hundred feet deep, its basin was once occupied by a glacier which filled it from the bottom to a point high above the present water-level, and being lavishly fed by the snows of the encompassing mountains, crawled slowly, like a mighty river, over the north rim of the basin, crushing and grinding the lower mountains that lay in its way, and it was only at the end of the ice period that this noble lake, at least in anything like its present form, came into existence. ","","Excepting the forests that have sprung up around its shores, the post-glacial changes that have taken place are scarcely appreciable. The sediments carried forward by the inflowing streams at the head of the lake have made a few square miles of meadow-land, and the breaking through of a moraine dam in the canon of the outlet has lowered the lake considerably, leaving shore benches and lines on the rocky promontories to mark the original level.
#
# With these comparatively unimportant exceptions, the lake itself and all its grandly sculptured, ice-scored, and moraine-streaked basin exist to-day in just about the condition they presented when first they came to the light towards the close of the Glacial Period. ","","The destructive action of man in clearing away the forests has not as yet effected any very marked change in general views. Perhaps about 150,000,000 feet of lumber for the Comstock mines has thus far been cut from the lake shores. But the business is being pushed so fervently from year to year, almost the entire basin must be stripped ere long of one of its most attractive features. One of the lumber companies at work here has contracted with mine owners to supply 36,000,000 feet of lumber and 60,000 cords of wood this season. It is estimated that the Tahoe basin still contains about 600,000,000 feet of lumber available for the mines. ","","In summer the woods resound with the outlandish noise of loggers and choppers and screaming mills; skiffs and steamboats skim the lovely blue water in work and play; and ever and anon as you thread the groves along shore you come upon groups of gay tourists sauntering about, gathering flowers, or resting luxuriously in the rosiny shade of the pines, some in easy picnic attire, others all ribbons and colors, glaring wildly amid the green leaves and frightening the wondering squirrels and birds. But winter brings rest.
#
# At sight of the first snowflake pleasure-seekers flee as from a plague, the ax leaves the woods, and the kind snow heals every scar. Contemplating the basin from any commanding hilltop, only pale curls of smoke seen at wide intervals betoken the existence of human dwellings. Like the bears, the few settlers that remain here are silently \"holed up.\" The snow covers their cabins as if they were bowlders, and when approached only a narrow shoveled-out passage, or tunnel, is found leading to the door. Some of the more enterprising winter dwellers drift about in boats in calm weather, catching trout for the Carson market,â€”for the lake, on account of its great depth, never freezes. They thus earn from thirty to forty dollars a month, and at the same time get rid of lonely dullness. A trapper may also be seen now and then shuffling along the shore on long Norwegian snow-shoes in pursuit of minks, fishers, and otters. ","","In this letter I intended only to say a good word for winter in the mountains, hoping to incite others to come and enjoy it, sketching our excursion to illustrate the ease and comfort with which such snowy winter rambles may be made; but I have written too much I fear about the snow to leave room for more than a thin outline. We went by rail to Lake Tahoe in Winter. 125 Carson, and from there set out by stage for Glenbrook.
#
# After ascending on wheels until we reached the snow-line, the driver attached his four horses to a sled, hoping thus to cross the summit, which is less than eight thousand feet high, without much difficulty. But mild weather had softened the snow, and the unfortunate animals, after floundering and wallowing through a mile of it, lay down exhausted with their heels in the air. Then we made our way on foot over to the lake. Next day, on a small steam-tug, we crossed the lake to McKinney's, on the west shore, where we were at home. Here we spent a few health-giving, delightful days, rowing, bathing, racing at lightning speed on snow-shoes down a mountain-side back of the house, and slipping about through the solemn, silent woods. Only the eldest of my companions ventured with me on the steep slopes. This was his first experience on snowshoes, and the several descents he made were the most remarkable specimens of falling locomotion that I ever had the fortune to witness. In shooting down steep declivities the long sled-runner-like shoes have to be kept parallel with firmly braced limbs. My friend, however, heedless of advice, launched himself in wild abandon, bouncing and diving, his limbs and shoes in chaotic entanglement, now in the snow, now in the air, whirling over and over in giddy rolls and somersaults that would shame the most extravagant performances of a circus acrobat. How original and inimitable he was!
#
# "],"stylingDirectives":[[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]],"csv":null,"csvError":null,"dependabotInfo":{"showConfigurationBanner":false,"configFilePath":null,"networkDependabotPath":"/fangtailin/langchain_MR_with_GCP_genai/network/updates","dismissConfigurationNoticePath":"/settings/dismiss-notice/dependabot_configuration_notice","configurationNoticeDismissed":null,"repoAlertsPath":"/fangtailin/langchain_MR_with_GCP_genai/security/dependabot","repoSecurityAndAnalysisPath":"/fangtailin/langchain_MR_with_GCP_genai/settings/security_analysis","repoOwnerIsOrg":false,"currentUserCanAdminRepo":false},"displayName":"small_text_named_muir_lake_tahoe_in_winter.txt","displayUrl":"https://github.com/fangtailin/langchain_MR_with_GCP_genai/blob/main/data/small_text_named_muir_lake_tahoe_in_winter.txt?raw=true","headerInfo":{"blobSize":"13 KB","deleteInfo":{"deletePath":null,"deleteTooltip":"You must be signed in to make or propose changes"},"editInfo":{"editTooltip":"You must be signed in to make or propose changes"},"ghDesktopPath":"https://desktop.github.com","gitLfsPath":null,"onBranch":true,"shortPath":"1586a80","siteNavLoginPath":"/login?return_to=https%3A%2F%2Fgithub.com%2Ffangtailin%2Flangchain_MR_with_GCP_genai%2Fblob%2Fmain%2Fdata%2Fsmall_text_named_muir_lake_tahoe_in_winter.txt","isCSV":false,"isRichtext":false,"toc":null,"lineInfo":{"truncatedLoc":"21","truncatedSloc":"11"},"mode":"file"},"image":false,"isCodeownersFile":null,"isValidLegacyIssueTemp
#
# late":false,"issueTemplateHelpUrl":"https://docs.github.com/articles/about-issue-and-pull-request-templates","issueTemplate":null,"discussionTemplate":null,"language":"Text","large":false,"loggedIn":false,"newDiscussionPath":"/fangtailin/langchain_MR_with_GCP_genai/discussions/new","newIssuePath":"/fangtailin/langchain_MR_with_GCP_genai/issues/new","planSupportInfo":{"repoIsFork":null,"repoOwnedByCurrentUser":null,"requestFullPath":"/fangtailin/langchain_MR_with_GCP_genai/blob/main/data/small_text_named_muir_lake_tahoe_in_winter.txt","showFreeOrgGatedFeatureMessage":null,"showPlanSupportBanner":null,"upgradeDataAttributes":null,"upgradePath":null},"publishBannersInfo":{"dismissActionNoticePath":"/settings/dismiss-notice/publish_action_from_dockerfile","dismissStackNoticePath":"/settings/dismiss-notice/publish_stack_from_file","releasePath":"/fangtailin/langchain_MR_with_GCP_genai/releases/new?marketplace=true","showPublishActionBanner":false,"showPublishStackBanner":false},"renderImageOrRaw":false,"richText":null,"renderedFileInfo":null,"tabSize":8,"topBannersInfo":{"overridingGlobalFundingFile":false,"globalPreferredFundingPath":null,"repoOwner":"fangtailin","repoName":"langchain_MR_with_GCP_genai","showInvalidCitationWarning":false,"citationHelpUrl":"https://docs.github.com/en/github/creating-cloning-and-archiving-repositories/creating-a-repository-on-github/about-citation-files","showDependabotConfigurationBanner":false,"actionsOnboardingTip":null},"truncated":false,"viewa
#
# ble":true,"workflowRedirectUrl":null,"symbols":{"timedOut":false,"notAnalyzed":true,"symbols":[]}},"copilotUserAccess":null,"csrf_tokens":{"/fangtailin/langchain_MR_with_GCP_genai/branches":{"post":"GmonOphRRdBfEz-R0utnBMOSQw3mzBJOcSmDmabN3U6TYCUcNPtcUUGNK1BSSicQfM6zYvQyWxvqGJY4_7W8IQ"}}},"title":"langchain_MR_with_GCP_genai/data/small_text_named_muir_lake_tahoe_in_winter.txt at main · fangtailin/langchain_MR_with_GCP_genai","locale":"en"}
#
# Wonderfully refreshing and exhilarating his queer capers must have been; for on coming to rest, with his runaway members divorced and lost, he would quietly gather himself, pick out the snow from his neck and ears, and say with preternatural solemnity, \"This, Muir, is the very poetry of motion.\"","","We also spent some rare evenings by the huge fire in McKinney's old cabin. The log walls are covered with trophies of the chase, for our host has been a great hunter in his day. Two live pet coons were frolicking on the floor while our grand old host smiled benignly and played with them, the firelight gleaming on his weathered face. How big he seems, thus brought into relief, and what a shadow he casts! The fragrant rosiny fire is the very god of the home. No wonder the old nations, with their fresher instincts, had their fireside gods. At last, when a mild snow-storm was blowing, we rowed to the lower end of the lake and completed our excursion by slipping on snow-shoes down the Truckee canon to the railroad."
#
#
# CONCISE SUMMARY:
#
# > Finished chain.
#
# > Finished chain.
# 'John Muir describes his trip to Lake Tahoe in winter. He writes about the beauty of the snow-covered mountains and lakes, and the fun he had snowshoeing and swimming in the icy lake. He also describes the wildlife he saw, including a bear and two pet coons.'

# %%
chain.run(lg_doc)

# There will be error and you can't get the summary
# Out:
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Write a concise summary of the following:
#
#
# "{"payload":{"allShortcutsEnabled":false,"fileTree":{"data":{"items":[{"name":"large_text_named_worked.txt","path":"data/large_text_named_worked.txt","contentType":"file"},{"name":"small_text_named_muir_lake_tahoe_in_winter.txt","path":"data/small_text_named_muir_lake_tahoe_in_winter.txt","contentType":"file"},{"name":"test.txt","path":"data/test.txt","contentType":"file"}],"totalCount":3},"":{"items":[{"name":"data","path":"data","contentType":"directory"},{"name":"LICENSE","path":"LICENSE","contentType":"file"},{"name":"README.md","path":"README.md","contentType":"file"}],"totalCount":3}},"fileTreeProcessingTime":4.1075859999999995,"foldersToFetch":[],"reducedMotionEnabled":null,"repo":{"id":666981890,"defaultBranch":"main","name":"langchain_MR_with_GCP_genai","ownerLogin":"fangtailin","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"2023-07-16T08:36:54.000Z","ownerAvatar":"https://avatars.githubusercontent.com/u/38515542?v=4","public":true,"private":false,"isOrgOwned":false},"refInfo":{"name":"main","listCacheKey":"v0:1689497119.0","canEdit":false,"refType":"branch","currentOid":"211b4e147268d1e756fe4fbb77d66d60bc55d6cd"},"path":"data/large_text_named_worked.txt","currentUser":null,"blob":{"rawLines":["February 2021Before college the two main things I worked on, outside of school,\r","were writing and programming. I didn't write essays. I wrote what\r","beginning writers were supposed to write then, and probably still\r","are: short stories.
#
# My stories were awful. They had hardly any plot,\r","just characters with strong feelings, which I imagined made them\r","deep.The first programs I tried writing were on the IBM 1401 that our\r","school district used for what was then called \"data processing.\"\r","This was in 9th grade, so I was 13 or 14. The school district's\r","1401 happened to be in the basement of our junior high school, and\r","my friend Rich Draves and I got permission to use it. It was like\r","a mini Bond villain's lair down there, with all these alien-looking\r","machines  CPU, disk drives, printer, card reader  sitting up\r","on a raised floor under bright fluorescent lights.The language we used was an early version of Fortran. You had to\r","type programs on punch cards, then stack them in the card reader\r","and press a button to load the program into memory and run it. The\r","result would ordinarily be to print something on the spectacularly\r","loud printer.I was puzzled by the 1401. I couldn't figure out what to do with\r","it. And in retrospect there's not much I could have done with it.\r","The only form of input to programs was data stored on punched cards,\r","and I didn't have any data stored on punched cards. The only other\r","option was to do things that didn't rely on any input, like calculate\r","approximations of pi, but I didn't know enough math to do anything\r","interesting of that type.
#
# So I'm not surprised I can't remember any\r","programs I wrote, because they can't have done much. My clearest\r","memory is of the moment I learned it was possible for programs not\r","to terminate, when one of mine didn't. On a machine without\r","time-sharing, this was a social as well as a technical error, as\r","the data center manager's expression made clear.With microcomputers, everything changed. Now you could have a\r","computer sitting right in front of you, on a desk, that could respond\r","to your keystrokes as it was running instead of just churning through\r","a stack of punch cards and then stopping. \r","[1]The first of my friends to get a microcomputer built it himself.\r","It was sold as a kit by Heathkit. I remember vividly how impressed\r","and envious I felt watching him sitting in front of it, typing\r","programs right into the computer.Computers were expensive in those days and it took me years of\r","nagging before I convinced my father to buy one, a TRS-80, in about\r","1980. The gold standard then was the Apple II, but a TRS-80 was\r","good enough. This was when I really started programming. I wrote\r","simple games, a program to predict how high my model rockets would\r","fly, and a word processor that my father used to write at least one\r","book.
#
# There was only room in memory for about 2 pages of text, so\r","he'd write 2 pages at a time and then print them out, but it was a\r","lot better than a typewriter.Though I liked programming, I didn't plan to study it in college.\r","In college I was going to study philosophy, which sounded much more\r","powerful. It seemed, to my naive high school self, to be the study\r","of the ultimate truths, compared to which the things studied in\r","other fields would be mere domain knowledge. What I discovered when\r","I got to college was that the other fields took up so much of the\r","space of ideas that there wasn't much left for these supposed\r","ultimate truths. All that seemed left for philosophy were edge cases\r","that people in other fields felt could safely be ignored.I couldn't have put this into words when I was 18. All I knew at\r","the time was that I kept taking philosophy courses and they kept\r","being boring. So I decided to switch to AI.AI was in the air in the mid 1980s, but there were two things\r","especially that made me want to work on it: a novel by Heinlein\r","called The Moon is a Harsh Mistress, which featured an intelligent\r","computer called Mike, and a PBS documentary that showed Terry\r","Winograd using SHRDLU. I haven't tried rereading The Moon is a Harsh\r","Mistress, so I don't know how well it has aged, but when I read it\r","I was drawn entirely into its world.
#
# It seemed only a matter of\r","time before we'd have Mike, and when I saw Winograd using SHRDLU,\r","it seemed like that time would be a few years at most. All you had\r","to do was teach SHRDLU more words.There weren't any classes in AI at Cornell then, not even graduate\r","classes, so I started trying to teach myself. Which meant learning\r","Lisp, since in those days Lisp was regarded as the language of AI.\r","The commonly used programming languages then were pretty primitive,\r","and programmers' ideas correspondingly so. The default language at\r","Cornell was a Pascal-like language called PL/I, and the situation\r","was similar elsewhere. Learning Lisp expanded my concept of a program\r","so fast that it was years before I started to have a sense of where\r","the new limits were. This was more like it; this was what I had\r","expected college to do. It wasn't happening in a class, like it was\r","supposed to, but that was ok. For the next couple years I was on a\r","roll. I knew what I was going to do.For my undergraduate thesis, I reverse-engineered SHRDLU. My God\r","did I love working on that program. It was a pleasing bit of code,\r","but what made it even more exciting was my belief  hard to imagine\r","now, but not unique in 1985  that it was already climbing the\r","lower slopes of intelligence.I had gotten into a program at Cornell that didn't make you choose\r","a major.
#
# You could take whatever classes you liked, and choose\r","whatever you liked to put on your degree. I of course chose \"Artificial\r","Intelligence.\" When I got the actual physical diploma, I was dismayed\r","to find that the quotes had been included, which made them read as\r","scare-quotes. At the time this bothered me, but now it seems amusingly\r","accurate, for reasons I was about to discover.I applied to 3 grad schools: MIT and Yale, which were renowned for\r","AI at the time, and Harvard, which I'd visited because Rich Draves\r","went there, and was also home to Bill Woods, who'd invented the\r","type of parser I used in my SHRDLU clone. Only Harvard accepted me,\r","so that was where I went.I don't remember the moment it happened, or if there even was a\r","specific moment, but during the first year of grad school I realized\r","that AI, as practiced at the time, was a hoax. By which I mean the\r","sort of AI in which a program that's told \"the dog is sitting on\r","the chair\" translates this into some formal representation and adds\r","it to the list of things it knows.What these programs really showed was that there's a subset of\r","natural language that's a formal language. But a very proper subset.\r","It was clear that there was an unbridgeable gap between what they\r","could do and actually understanding natural language. It was not,\r","in fact, simply a matter of teaching SHRDLU more words.
#
# That whole\r","way of doing AI, with explicit data structures representing concepts,\r","was not going to work. Its brokenness did, as so often happens,\r","generate a lot of opportunities to write papers about various\r","band-aids that could be applied to it, but it was never going to\r","get us Mike.So I looked around to see what I could salvage from the wreckage\r","of my plans, and there was Lisp. I knew from experience that Lisp\r","was interesting for its own sake and not just for its association\r","with AI, even though that was the main reason people cared about\r","it at the time. So I decided to focus on Lisp. In fact, I decided\r","to write a book about Lisp hacking. It's scary to think how little\r","I knew about Lisp hacking when I started writing that book. But\r","there's nothing like writing a book about something to help you\r","learn it. The book, On Lisp, wasn't published till 1993, but I wrote\r","much of it in grad school.Computer Science is an uneasy alliance between two halves, theory\r","and systems. The theory people prove things, and the systems people\r","build things. I wanted to build things. I had plenty of respect for\r","theory  indeed, a sneaking suspicion that it was the more admirable\r","of the two halves  but building things seemed so much more exciting.The problem with systems work, though, was that it didn't last.\r","Any program you wrote today, no matter how good, would be obsolete\r","in a couple decades at best.
#
# People might mention your software in\r","footnotes, but no one would actually use it. And indeed, it would\r","seem very feeble work. Only people with a sense of the history of\r","the field would even realize that, in its time, it had been good.There were some surplus Xerox Dandelions floating around the computer\r","lab at one point. Anyone who wanted one to play around with could\r","have one. I was briefly tempted, but they were so slow by present\r","standards; what was the point? No one else wanted one either, so\r","off they went. That was what happened to systems work.I wanted not just to build things, but to build things that would\r","last.In this dissatisfied state I went in 1988 to visit Rich Draves at\r","CMU, where he was in grad school. One day I went to visit the\r","Carnegie Institute, where I'd spent a lot of time as a kid. While\r","looking at a painting there I realized something that might seem\r","obvious, but was a big surprise to me. There, right on the wall,\r","was something you could make that would last. Paintings didn't\r","become obsolete. Some of the best ones were hundreds of years old.And moreover this was something you could make a living doing. Not\r","as easily as you could by writing software, of course, but I thought\r","if you were really industrious and lived really cheaply, it had to\r","be possible to make enough to survive. And as an artist you could\r","be truly independent.
#
# You wouldn't have a boss, or even need to get\r","research funding.I had always liked looking at paintings. Could I make them? I had\r","no idea. I'd never imagined it was even possible. I knew intellectually\r","that people made art  that it didn't just appear spontaneously\r"," but it was as if the people who made it were a different species.\r","They either lived long ago or were mysterious geniuses doing strange\r","things in profiles in Life magazine. The idea of actually being\r","able to make art, to put that verb before that noun, seemed almost\r","miraculous.That fall I started taking art classes at Harvard. Grad students\r","could take classes in any department, and my advisor, Tom Cheatham,\r","was very easy going. If he even knew about the strange classes I\r","was taking, he never said anything.So now I was in a PhD program in computer science, yet planning to\r","be an artist, yet also genuinely in love with Lisp hacking and\r","working away at On Lisp. In other words, like many a grad student,\r","I was working energetically on multiple projects that were not my\r","thesis.I didn't see a way out of this situation. I didn't want to drop out\r","of grad school, but how else was I going to get out? I remember\r","when my friend Robert Morris got kicked out of Cornell for writing\r","the internet worm of 1988, I was envious that he'd found such a\r","spectacular way to get out of grad school.Then one day in April 1990 a crack appeared in the wall.
#
# I ran into\r","professor Cheatham and he asked if I was far enough along to graduate\r","that June. I didn't have a word of my dissertation written, but in\r","what must have been the quickest bit of thinking in my life, I\r","decided to take a shot at writing one in the 5 weeks or so that\r","remained before the deadline, reusing parts of On Lisp where I\r","could, and I was able to respond, with no perceptible delay \"Yes,\r","I think so. I'll give you something to read in a few days.\"I picked applications of continuations as the topic. In retrospect\r","I should have written about macros and embedded languages. There's\r","a whole world there that's barely been explored. But all I wanted\r","was to get out of grad school, and my rapidly written dissertation\r","sufficed, just barely.Meanwhile I was applying to art schools. I applied to two: RISD in\r","the US, and the Accademia di Belli Arti in Florence, which, because\r","it was the oldest art school, I imagined would be good. RISD accepted\r","me, and I never heard back from the Accademia, so off to Providence\r","I went.I'd applied for the BFA program at RISD, which meant in effect that\r","I had to go to college again. This was not as strange as it sounds,\r","because I was only 25, and art schools are full of people of different\r","ages. RISD counted me as a transfer sophomore and said I had to do\r","the foundation that summer.
#
# The foundation means the classes that\r","everyone has to take in fundamental subjects like drawing, color,\r","and design.Toward the end of the summer I got a big surprise: a letter from\r","the Accademia, which had been delayed because they'd sent it to\r","Cambridge England instead of Cambridge Massachusetts, inviting me\r","to take the entrance exam in Florence that fall. This was now only\r","weeks away. My nice landlady let me leave my stuff in her attic. I\r","had some money saved from consulting work I'd done in grad school;\r","there was probably enough to last a year if I lived cheaply. Now\r","all I had to do was learn Italian.Only stranieri (foreigners) had to take this entrance exam. In\r","retrospect it may well have been a way of excluding them, because\r","there were so many stranieri attracted by the idea of studying\r","art in Florence that the Italian students would otherwise have been\r","outnumbered. I was in decent shape at painting and drawing from the\r","RISD foundation that summer, but I still don't know how I managed\r","to pass the written exam. I remember that I answered the essay\r","question by writing about Cezanne, and that I cranked up the\r","intellectual level as high as I could to make the most of my limited\r","vocabulary.
#
# \r","[2]I'm only up to age 25 and already there are such conspicuous patterns.\r","Here I was, yet again about to attend some august institution in\r","the hopes of learning about some prestigious subject, and yet again\r","about to be disappointed. The students and faculty in the painting\r","department at the Accademia were the nicest people you could imagine,\r","but they had long since arrived at an arrangement whereby the\r","students wouldn't require the faculty to teach anything, and in\r","return the faculty wouldn't require the students to learn anything.\r","And at the same time all involved would adhere outwardly to the\r","conventions of a 19th century atelier. We actually had one of those\r","little stoves, fed with kindling, that you see in 19th century\r","studio paintings, and a nude model sitting as close to it as possible\r","without getting burned. Except hardly anyone else painted her besides\r","me. The rest of the students spent their time chatting or occasionally\r","trying to imitate things they'd seen in American art magazines.Our model turned out to live just down the street from me. She made\r","a living from a combination of modelling and making fakes for a\r","local antique dealer. She'd copy an obscure old painting out of a\r","book, and then he'd take the copy and maltreat it to make it look\r","old. \r","[3]While I was a student at the Accademia I started painting still\r","lives in my bedroom at night.
#
# These paintings were tiny, because\r","the room was, and because I painted them on leftover scraps of\r","canvas, which was all I could afford at the time. Painting still\r","lives is different from painting people, because the subject, as\r","its name suggests, can't move. People can't sit for more than about\r","15 minutes at a time, and when they do they don't sit very still.\r","So the traditional m.o. for painting people is to know how to paint\r","a generic person, which you then modify to match the specific person\r","you're painting. Whereas a still life you can, if you want, copy\r","pixel by pixel from what you're seeing. You don't want to stop\r","there, of course, or you get merely photographic accuracy, and what\r","makes a still life interesting is that it's been through a head.\r","You want to emphasize the visual cues that tell you, for example,\r","that the reason the color changes suddenly at a certain point is\r","that it's the edge of an object. By subtly emphasizing such things\r","you can make paintings that are more realistic than photographs not\r","just in some metaphorical sense, but in the strict information-theoretic\r","sense. \r","[4]I liked painting still lives because I was curious about what I was\r","seeing. In everyday life, we aren't consciously aware of much we're\r","seeing.
#
# Most visual perception is handled by low-level processes\r","that merely tell your brain \"that's a water droplet\" without telling\r","you details like where the lightest and darkest points are, or\r","\"that's a bush\" without telling you the shape and position of every\r","leaf. This is a feature of brains, not a bug. In everyday life it\r","would be distracting to notice every leaf on every bush. But when\r","you have to paint something, you have to look more closely, and\r","when you do there's a lot to see. You can still be noticing new\r","things after days of trying to paint something people usually take\r","for granted, just as you can  after\r","days of trying to write an essay about something people usually\r","take for granted.This is not the only way to paint. I'm not 100% sure it's even a\r","good way to paint. But it seemed a good enough bet to be worth\r","trying.Our teacher, professor Ulivi, was a nice guy. He could see I worked\r","hard, and gave me a good grade, which he wrote down in a sort of\r","passport each student had. But the Accademia wasn't teaching me\r","anything except Italian, and my money was running out, so at the\r","end of the first year I went back to the US.I wanted to go back to RISD, but I was now broke and RISD was very\r","expensive, so I decided to get a job for a year and then return to\r","RISD the next fall. I got one at a company called Interleaf, which\r","made software for creating documents.
#
# You mean like Microsoft Word?\r","Exactly. That was how I learned that low end software tends to eat\r","high end software. But Interleaf still had a few years to live yet.\r","[5]Interleaf had done something pretty bold. Inspired by Emacs, they'd\r","added a scripting language, and even made the scripting language a\r","dialect of Lisp. Now they wanted a Lisp hacker to write things in\r","it. This was the closest thing I've had to a normal job, and I\r","hereby apologize to my boss and coworkers, because I was a bad\r","employee. Their Lisp was the thinnest icing on a giant C cake, and\r","since I didn't know C and didn't want to learn it, I never understood\r","most of the software. Plus I was terribly irresponsible. This was\r","back when a programming job meant showing up every day during certain\r","working hours. That seemed unnatural to me, and on this point the\r","rest of the world is coming around to my way of thinking, but at\r","the time it caused a lot of friction. Toward the end of the year I\r","spent much of my time surreptitiously working on On Lisp, which I\r","had by this time gotten a contract to publish.The good part was that I got paid huge amounts of money, especially\r","by art student standards. In Florence, after paying my part of the\r","rent, my budget for everything else had been $7 a day. Now I was\r","getting paid more than 4 times that every hour, even when I was\r","just sitting in a meeting.
#
# By living cheaply I not only managed to\r","save enough to go back to RISD, but also paid off my college loans.I learned some useful things at Interleaf, though they were mostly\r","about what not to do. I learned that it's better for technology\r","companies to be run by product people than sales people (though\r","sales is a real skill and people who are good at it are really good\r","at it), that it leads to bugs when code is edited by too many people,\r","that cheap office space is no bargain if it's depressing, that\r","planned meetings are inferior to corridor conversations, that big,\r","bureaucratic customers are a dangerous source of money, and that\r","there's not much overlap between conventional office hours and the\r","optimal time for hacking, or conventional offices and the optimal\r","place for it.But the most important thing I learned, and which I used in both\r","Viaweb and Y Combinator, is that the low end eats the high end:\r","that it's good to be the \"entry level\" option, even though that\r","will be less prestigious, because if you're not, someone else will\r","be, and will squash you against the ceiling. Which in turn means\r","that prestige is a danger sign.When I left to go back to RISD the next fall, I arranged to do\r","freelance work for the group that did projects for customers, and\r","this was how I survived for the next several years.
#
# When I came\r","back to visit for a project later on, someone told me about a new\r","thing called HTML, which was, as he described it, a derivative of\r","SGML. Markup language enthusiasts were an occupational hazard at\r","Interleaf and I ignored him, but this HTML thing later became a big\r","part of my life.In the fall of 1992 I moved back to Providence to continue at RISD.\r","The foundation had merely been intro stuff, and the Accademia had\r","been a (very civilized) joke. Now I was going to see what real art\r","school was like. But alas it was more like the Accademia than not.\r","Better organized, certainly, and a lot more expensive, but it was\r","now becoming clear that art school did not bear the same relationship\r","to art that medical school bore to medicine. At least not the\r","painting department. The textile department, which my next door\r","neighbor belonged to, seemed to be pretty rigorous. No doubt\r","illustration and architecture were too. But painting was post-rigorous.\r","Painting students were supposed to express themselves, which to the\r","more worldly ones meant to try to cook up some sort of distinctive\r","signature style.A signature style is the visual equivalent of what in show business\r","is known as a \"schtick\": something that immediately identifies the\r","work as yours and no one else's. For example, when you see a painting\r","that looks like a certain kind of cartoon, you know it's by Roy\r","Lichtenstein.
#
# So if you see a big painting of this type hanging in\r","the apartment of a hedge fund manager, you know he paid millions\r","of dollars for it. That's not always why artists have a signature\r","style, but it's usually why buyers pay a lot for such work.\r","[6]There were plenty of earnest students too: kids who \"could draw\"\r","in high school, and now had come to what was supposed to be the\r","best art school in the country, to learn to draw even better. They\r","tended to be confused and demoralized by what they found at RISD,\r","but they kept going, because painting was what they did. I was not\r","one of the kids who could draw in high school, but at RISD I was\r","definitely closer to their tribe than the tribe of signature style\r","seekers.I learned a lot in the color class I took at RISD, but otherwise I\r","was basically teaching myself to paint, and I could do that for\r","free. So in 1993 I dropped out. I hung around Providence for a bit,\r","and then my college friend Nancy Parmet did me a big favor. A\r","rent-controlled apartment in a building her mother owned in New\r","York was becoming vacant. Did I want it? It wasn't much more than\r","my current place, and New York was supposed to be where the artists\r","were. So yes, I wanted it!\r","[7]Asterix comics begin by zooming in on a tiny corner of Roman Gaul\r","that turns out not to be controlled by the Romans.
#
# You can do\r","something similar on a map of New York City: if you zoom in on the\r","Upper East Side, there's a tiny corner that's not rich, or at least\r","wasn't in 1993. It's called Yorkville, and that was my new home.\r","Now I was a New York artist  in the strictly technical sense of\r","making paintings and living in New York.I was nervous about money, because I could sense that Interleaf was\r","on the way down. Freelance Lisp hacking work was very rare, and I\r","didn't want to have to program in another language, which in those\r","days would have meant C++ if I was lucky. So with my unerring nose\r","for financial opportunity, I decided to write another book on Lisp.\r","This would be a popular book, the sort of book that could be used\r","as a textbook. I imagined myself living frugally off the royalties\r","and spending all my time painting. (The painting on the cover of\r","this book, ANSI Common Lisp, is one that I painted around this\r","time. )The best thing about New York for me was the presence of Idelle and\r","Julian Weber. Idelle Weber was a painter, one of the early\r","photorealists, and I'd taken her painting class at Harvard. I've\r","never known a teacher more beloved by her students. Large numbers\r","of former students kept in touch with her, including me.
#
# After I\r","moved to New York I became her de facto studio assistant.She liked to paint on big, square canvases, 4 to 5 feet on a side.\r","One day in late 1994 as I was stretching one of these monsters there\r","was something on the radio about a famous fund manager. He wasn't\r","that much older than me, and was super rich. The thought suddenly\r","occurred to me: why don't I become rich? Then I'll be able to work\r","on whatever I want.Meanwhile I'd been hearing more and more about this new thing called\r","the World Wide Web. Robert Morris showed it to me when I visited\r","him in Cambridge, where he was now in grad school at Harvard. It\r","seemed to me that the web would be a big deal. I'd seen what graphical\r","user interfaces had done for the popularity of microcomputers. It\r","seemed like the web would do the same for the internet.If I wanted to get rich, here was the next train leaving the station.\r","I was right about that part. What I got wrong was the idea. I decided\r","we should start a company to put art galleries online. I can't\r","honestly say, after reading so many Y Combinator applications, that\r","this was the worst startup idea ever, but it was up there. Art\r","galleries didn't want to be online, and still don't, not the fancy\r","ones. That's not how they sell. I wrote some software to generate\r","web sites for galleries, and Robert wrote some to resize images and\r","set up an http server to serve the pages.
#
# Then we tried to sign up\r","galleries. To call this a difficult sale would be an understatement.\r","It was difficult to give away. A few galleries let us make sites\r","for them for free, but none paid us.Then some online stores started to appear, and I realized that\r","except for the order buttons they were identical to the sites we'd\r","been generating for galleries. This impressive-sounding thing called\r","an \"internet storefront\" was something we already knew how to build.So in the summer of 1995, after I submitted the camera-ready copy\r","of ANSI Common Lisp to the publishers, we started trying to write\r","software to build online stores. At first this was going to be\r","normal desktop software, which in those days meant Windows software.\r","That was an alarming prospect, because neither of us knew how to\r","write Windows software or wanted to learn. We lived in the Unix\r","world. But we decided we'd at least try writing a prototype store\r","builder on Unix. Robert wrote a shopping cart, and I wrote a new\r","site generator for stores  in Lisp, of course.We were working out of Robert's apartment in Cambridge. His roommate\r","was away for big chunks of time, during which I got to sleep in his\r","room. For some reason there was no bed frame or sheets, just a\r","mattress on the floor.
#
# One morning as I was lying on this mattress\r","I had an idea that made me sit up like a capital L. What if we ran\r","the software on the server, and let users control it by clicking\r","on links? Then we'd never have to write anything to run on users'\r","computers. We could generate the sites on the same server we'd serve\r","them from. Users wouldn't need anything more than a browser.This kind of software, known as a web app, is common now, but at\r","the time it wasn't clear that it was even possible. To find out,\r","we decided to try making a version of our store builder that you\r","could control through the browser. A couple days later, on August\r","12, we had one that worked. The UI was horrible, but it proved you\r","could build a whole store through the browser, without any client\r","software or typing anything into the command line on the server.Now we felt like we were really onto something. I had visions of a\r","whole new generation of software working this way. You wouldn't\r","need versions, or ports, or any of that crap. At Interleaf there\r","had been a whole group called Release Engineering that seemed to\r","be at least as big as the group that actually wrote the software.\r","Now you could just update the software right on the server.We started a new company we called Viaweb, after the fact that our\r","software worked via the web, and we got $10,000 in seed funding\r","from Idelle's husband Julian.
#
# In return for that and doing the\r","initial legal work and giving us business advice, we gave him 10%\r","of the company. Ten years later this deal became the model for Y\r","Combinator's. We knew founders needed something like this, because\r","we'd needed it ourselves.At this stage I had a negative net worth, because the thousand\r","dollars or so I had in the bank was more than counterbalanced by\r","what I owed the government in taxes. (Had I diligently set aside\r","the proper proportion of the money I'd made consulting for Interleaf?\r","No, I had not.) So although Robert had his graduate student stipend,\r","I needed that seed funding to live on.We originally hoped to launch in September, but we got more ambitious\r","about the software as we worked on it. Eventually we managed to\r","build a WYSIWYG site builder, in the sense that as you were creating\r","pages, they looked exactly like the static ones that would be\r","generated later, except that instead of leading to static pages,\r","the links all referred to closures stored in a hash table on the\r","server.It helped to have studied art, because the main goal of an online\r","store builder is to make users look legit, and the key to looking\r","legit is high production values. If you get page layouts and fonts\r","and colors right, you can make a guy running a store out of his\r","bedroom look more legit than a big company.
#
# (If you're curious why my site looks so old-fashioned, it's because\r","it's still made with this software. It may look clunky today, but\r","in 1996 it was the last word in slick. )In September, Robert rebelled. \"We've been working on this for a\r","month,\" he said, \"and it's still not done.\" This is funny in\r","retrospect, because he would still be working on it almost 3 years\r","later. But I decided it might be prudent to recruit more programmers,\r","and I asked Robert who else in grad school with him was really good.\r","He recommended Trevor Blackwell, which surprised me at first, because\r","at that point I knew Trevor mainly for his plan to reduce everything\r","in his life to a stack of notecards, which he carried around with\r","him. But Rtm was right, as usual. Trevor turned out to be a\r","frighteningly effective hacker.It was a lot of fun working with Robert and Trevor. They're the two\r","most independent-minded people \r","I know, and in completely different\r","ways. If you could see inside Rtm's brain it would look like a\r","colonial New England church, and if you could see inside Trevor's\r","it would look like the worst excesses of Austrian Rococo.We opened for business, with 6 stores, in January 1996. It was just\r","as well we waited a few months, because although we worried we were\r","late, we were actually almost fatally early.
#
# There was a lot of\r","talk in the press then about ecommerce, but not many people actually\r","wanted online stores.\r","[8]There were three main parts to the software: the editor, which\r","people used to build sites and which I wrote, the shopping cart,\r","which Robert wrote, and the manager, which kept track of orders and\r","statistics, and which Trevor wrote. In its time, the editor was one\r","of the best general-purpose site builders. I kept the code tight\r","and didn't have to integrate with any other software except Robert's\r","and Trevor's, so it was quite fun to work on. If all I'd had to do\r","was work on this software, the next 3 years would have been the\r","easiest of my life. Unfortunately I had to do a lot more, all of\r","it stuff I was worse at than programming, and the next 3 years were\r","instead the most stressful.There were a lot of startups making ecommerce software in the second\r","half of the 90s. We were determined to be the Microsoft Word, not\r","the Interleaf. Which meant being easy to use and inexpensive. It\r","was lucky for us that we were poor, because that caused us to make\r","Viaweb even more inexpensive than we realized. We charged $100 a\r","month for a small store and $300 a month for a big one. This low\r","price was a big attraction, and a constant thorn in the sides of\r","competitors, but it wasn't because of some clever insight that we\r","set the price low.
#
# We had no idea what businesses paid for things.\r","$300 a month seemed like a lot of money to us.We did a lot of things right by accident like that. For example,\r","we did what's now called \"doing things that \r","don't scale,\" although\r","at the time we would have described it as \"being so lame that we're\r","driven to the most desperate measures to get users.\" The most common\r","of which was building stores for them. This seemed particularly\r","humiliating, since the whole raison d'etre of our software was that\r","people could use it to make their own stores. But anything to get\r","users.We learned a lot more about retail than we wanted to know. For\r","example, that if you could only have a small image of a man's shirt\r","(and all images were small then by present standards), it was better\r","to have a closeup of the collar than a picture of the whole shirt.\r","The reason I remember learning this was that it meant I had to\r","rescan about 30 images of men's shirts. My first set of scans were\r","so beautiful too.Though this felt wrong, it was exactly the right thing to be doing.\r","Building stores for users taught us about retail, and about how it\r","felt to use our software.
#
# I was initially both mystified and repelled\r","by \"business\" and thought we needed a \"business person\" to be in\r","charge of it, but once we started to get users, I was converted,\r","in much the same way I was converted to \r","fatherhood once I had kids.\r","Whatever users wanted, I was all theirs. Maybe one day we'd have\r","so many users that I couldn't scan their images for them, but in\r","the meantime there was nothing more important to do.Another thing I didn't get at the time is that \r","growth rate is the\r","ultimate test of a startup. Our growth rate was fine. We had about\r","70 stores at the end of 1996 and about 500 at the end of 1997. I\r","mistakenly thought the thing that mattered was the absolute number\r","of users. And that is the thing that matters in the sense that\r","that's how much money you're making, and if you're not making enough,\r","you might go out of business. But in the long term the growth rate\r","takes care of the absolute number. If we'd been a startup I was\r","advising at Y Combinator, I would have said: Stop being so stressed\r","out, because you're doing fine. You're growing 7x a year. Just don't\r","hire too many more people and you'll soon be profitable, and then\r","you'll control your own destiny.Alas I hired lots more people, partly because our investors wanted\r","me to, and partly because that's what startups did during the\r","Internet Bubble. A company with just a handful of employees would\r","have seemed amateurish.
#
# So we didn't reach breakeven until about\r","when Yahoo bought us in the summer of 1998. Which in turn meant we\r","were at the mercy of investors for the entire life of the company.\r","And since both we and our investors were noobs at startups, the\r","result was a mess even by startup standards.It was a huge relief when Yahoo bought us. In principle our Viaweb\r","stock was valuable. It was a share in a business that was profitable\r","and growing rapidly. But it didn't feel very valuable to me; I had\r","no idea how to value a business, but I was all too keenly aware of\r","the near-death experiences we seemed to have every few months. Nor\r","had I changed my grad student lifestyle significantly since we\r","started. So when Yahoo bought us it felt like going from rags to\r","riches. Since we were going to California, I bought a car, a yellow\r","1998 VW GTI. I remember thinking that its leather seats alone were\r","by far the most luxurious thing I owned.The next year, from the summer of 1998 to the summer of 1999, must\r","have been the least productive of my life. I didn't realize it at\r","the time, but I was worn out from the effort and stress of running\r","Viaweb. For a while after I got to California I tried to continue\r","my usual m.o. of programming till 3 in the morning, but fatigue\r","combined with Yahoo's prematurely aged\r","culture and grim cube farm\r","in Santa Clara gradually dragged me down.
#
# After a few months it\r","felt disconcertingly like working at Interleaf.Yahoo had given us a lot of options when they bought us. At the\r","time I thought Yahoo was so overvalued that they'd never be worth\r","anything, but to my astonishment the stock went up 5x in the next\r","year. I hung on till the first chunk of options vested, then in the\r","summer of 1999 I left. It had been so long since I'd painted anything\r","that I'd half forgotten why I was doing this. My brain had been\r","entirely full of software and men's shirts for 4 years. But I had\r","done this to get rich so I could paint, I reminded myself, and now\r","I was rich, so I should go paint.When I said I was leaving, my boss at Yahoo had a long conversation\r","with me about my plans. I told him all about the kinds of pictures\r","I wanted to paint. At the time I was touched that he took such an\r","interest in me. Now I realize it was because he thought I was lying.\r","My options at that point were worth about $2 million a month. If I\r","was leaving that kind of money on the table, it could only be to\r","go and start some new startup, and if I did, I might take people\r","with me. This was the height of the Internet Bubble, and Yahoo was\r","ground zero of it. My boss was at that moment a billionaire.
#
# Leaving\r","then to start a new startup must have seemed to him an insanely,\r","and yet also plausibly, ambitious plan.But I really was quitting to paint, and I started immediately.\r","There was no time to lose. I'd already burned 4 years getting rich.\r","Now when I talk to founders who are leaving after selling their\r","companies, my advice is always the same: take a vacation. That's\r","what I should have done, just gone off somewhere and done nothing\r","for a month or two, but the idea never occurred to me.So I tried to paint, but I just didn't seem to have any energy or\r","ambition. Part of the problem was that I didn't know many people\r","in California. I'd compounded this problem by buying a house up in\r","the Santa Cruz Mountains, with a beautiful view but miles from\r","anywhere. I stuck it out for a few more months, then in desperation\r","I went back to New York, where unless you understand about rent\r","control you'll be surprised to hear I still had my apartment, sealed\r","up like a tomb of my old life. Idelle was in New York at least, and\r","there were other people trying to paint there, even though I didn't\r","know any of them.When I got back to New York I resumed my old life, except now I was\r","rich. It was as weird as it sounds. I resumed all my old patterns,\r","except now there were doors where there hadn't been.
#
# Now when I was\r","tired of walking, all I had to do was raise my hand, and (unless\r","it was raining) a taxi would stop to pick me up. Now when I walked\r","past charming little restaurants I could go in and order lunch. It\r","was exciting for a while. Painting started to go better. I experimented\r","with a new kind of still life where I'd paint one painting in the\r","old way, then photograph it and print it, blown up, on canvas, and\r","then use that as the underpainting for a second still life, painted\r","from the same objects (which hopefully hadn't rotted yet).Meanwhile I looked for an apartment to buy. Now I could actually\r","choose what neighborhood to live in. Where, I asked myself and\r","various real estate agents, is the Cambridge of New York? Aided by\r","occasional visits to actual Cambridge, I gradually realized there\r","wasn't one. Huh.Around this time, in the spring of 2000, I had an idea. It was clear\r","from our experience with Viaweb that web apps were the future. Why\r","not build a web app for making web apps? Why not let people edit\r","code on our server through the browser, and then host the resulting\r","applications for them?\r","[9]\r","You could run all sorts of services\r","on the servers that these applications could use just by making an\r","API call: making and receiving phone calls, manipulating images,\r","taking credit card payments, etc.I got so excited about this idea that I couldn't think about anything\r","else.
#
# It seemed obvious that this was the future. I didn't particularly\r","want to start another company, but it was clear that this idea would\r","have to be embodied as one, so I decided to move to Cambridge and\r","start it. I hoped to lure Robert into working on it with me, but\r","there I ran into a hitch. Robert was now a postdoc at MIT, and\r","though he'd made a lot of money the last time I'd lured him into\r","working on one of my schemes, it had also been a huge time sink.\r","So while he agreed that it sounded like a plausible idea, he firmly\r","refused to work on it.Hmph. Well, I'd do it myself then. I recruited Dan Giffin, who had\r","worked for Viaweb, and two undergrads who wanted summer jobs, and\r","we got to work trying to build what it's now clear is about twenty\r","companies and several open source projects worth of software. The\r","language for defining applications would of course be a dialect of\r","Lisp. But I wasn't so naive as to assume I could spring an overt\r","Lisp on a general audience; we'd hide the parentheses, like Dylan\r","did.By then there was a name for the kind of company Viaweb was, an\r","\"application service provider,\" or ASP.
#
# This name didn't last long\r","before it was replaced by \"software as a service,\" but it was current\r","for long enough that I named this new company after it: it was going\r","to be called Aspra.I started working on the application builder, Dan worked on network\r","infrastructure, and the two undergrads worked on the first two\r","services (images and phone calls). But about halfway through the\r","summer I realized I really didn't want to run a company  especially\r","not a big one, which it was looking like this would have to be. I'd\r","only started Viaweb because I needed the money. Now that I didn't\r","need money anymore, why was I doing this? If this vision had to be\r","realized as a company, then screw the vision. I'd build a subset\r","that could be done as an open source project.Much to my surprise, the time I spent working on this stuff was not\r","wasted after all. After we started Y Combinator, I would often\r","encounter startups working on parts of this new architecture, and\r","it was very useful to have spent so much time thinking about it and\r","even trying to write some of it.The subset I would build as an open source project was the new Lisp,\r","whose parentheses I now wouldn't even have to hide.
#
# A lot of Lisp\r","hackers dream of building a new Lisp, partly because one of the\r","distinctive features of the language is that it has dialects, and\r","partly, I think, because we have in our minds a Platonic form of\r","Lisp that all existing dialects fall short of. I certainly did. So\r","at the end of the summer Dan and I switched to working on this new\r","dialect of Lisp, which I called Arc, in a house I bought in Cambridge.The following spring, lightning struck. I was invited to give a\r","talk at a Lisp conference, so I gave one about how we'd used Lisp\r","at Viaweb. Afterward I put a postscript file of this talk online,\r","on paulgraham.com, which I'd created years before using Viaweb but\r","had never used for anything. In one day it got 30,000 page views.\r","What on earth had happened? The referring urls showed that someone\r","had posted it on Slashdot.\r","[10]Wow, I thought, there's an audience. If I write something and put\r","it on the web, anyone can read it. That may seem obvious now, but\r","it was surprising then. In the print era there was a narrow channel\r","to readers, guarded by fierce monsters known as editors. The only\r","way to get an audience for anything you wrote was to get it published\r","as a book, or in a newspaper or magazine. Now anyone could publish\r","anything.This had been possible in principle since 1993, but not many people\r","had realized it yet.
#
# ...
#
# ing-a-repository-on-github/about-citation-files","showDependabotConfigurationBanner":false,"actionsOnboardingTip":null},"truncated":false,"viewable":true,"workflowRedirectUrl":null,"symbols":{"timedOut":false,"notAnalyzed":true,"symbols":[]}},"copilotUserAccess":null,"csrf_tokens":{"/fangtailin/langchain_MR_with_GCP_genai/branches":{"post":"2HQxDM-E35BSprJaOetJIMMeYyHZ_WyQLZayzYjY4e7mgHOuGbx9KvG9oUvj-K-yct7wwFWj-vxJk55mPovGkg"}}},"title":"langchain_MR_with_GCP_genai/data/large_text_named_worked.txt at main · fangtailin/langchain_MR_with_GCP_genai","locale":"en"}
#
# You actually have to respond to the misinterpretations,\r","because the assumption that you're present in the conversation means\r","that not responding to any sufficiently upvoted misinterpretation\r","reads as a tacit admission that it's correct. But that in turn\r","encourages more; anyone who wants to pick a fight with you senses\r","that now is their chance. [18]\r","The worst thing about leaving YC was not working with Jessica\r","anymore. We'd been working on YC almost the whole time we'd known\r","each other, and we'd neither tried nor wanted to separate it from\r","our personal lives, so leaving was like pulling up a deeply rooted\r","tree. [19]\r","One way to get more precise about the concept of invented vs\r","discovered is to talk about space aliens. Any sufficiently advanced\r","alien civilization would certainly know about the Pythagorean\r","theorem, for example. I believe, though with less certainty, that\r","they would also know about the Lisp in McCarthy's 1960 paper.But if so there's no reason to suppose that this is the limit of\r","the language that might be known to them. Presumably aliens need\r","numbers and errors and I/O too. So it seems likely there exists at\r","least one path out of McCarthy's Lisp along which discoveredness\r","is preserved.Thanks to Trevor Blackwell, John Collison, Patrick Collison, Daniel\r","Gackle, Ralph Hazell, Jessica Livingston, Robert Morris, and Harj\r","Taggar for reading drafts of this."
#
#
# CONCISE SUMMARY:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      71         try:
# ---> 72             return callable_(*args, **kwargs)
#      73         except grpc.RpcError as exc:
#
# /usr/local/lib/python3.10/dist-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1029                                       wait_for_ready, compression)
# -> 1030         return _end_unary_response_blocking(state, call, False, None)
#    1031
#
# /usr/local/lib/python3.10/dist-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     909     else:
# --> 910         raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
#     911
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "Request contains an invalid argument."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:173.194.74.95:443 {grpc_message:"Request contains an invalid argument.", grpc_status:3, created_time:"2023-07-17T01:49:38.561215341+00:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# InvalidArgument                           Traceback (most recent call last)
# <ipython-input-39-1dcc18bdf07b> in <cell line: 1>()
# ----> 1 chain.run(lg_doc)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     438             if len(args) != 1:
#     439                 raise ValueError("`run` supports only one positional argument.")
# --> 440             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     441                 _output_key
#     442             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     241         except (KeyboardInterrupt, Exception) as e:
#     242             run_manager.on_chain_error(e)
# --> 243             raise e
#     244         run_manager.on_chain_end(outputs)
#     245         final_outputs: Dict[str, Any] = self.prep_outputs(
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     235         try:
#     236             outputs = (
# --> 237                 self._call(inputs, run_manager=run_manager)
#     238                 if new_arg_supported
#     239                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/base.py in _call(self, inputs, run_manager)
#     104         # Other keys are assumed to be needed for LLM prediction
#     105         other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 106         output, extra_return_dict = self.combine_docs(
#     107             docs, callbacks=_run_manager.get_child(), **other_keys
#     108         )
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/stuff.py in combine_docs(self, docs, callbacks, **kwargs)
#     163         inputs = self._get_inputs(docs, **kwargs)
#     164         # Call predict on the LLM.
# --> 165         return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#     166
#     167     async def acombine_docs(
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in predict(self, callbacks, **kwargs)
#     250                 completion = llm.predict(adjective="funny")
#     251         """
# --> 252         return self(kwargs, callbacks=callbacks)[self.output_key]
#     253
#     254     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     241         except (KeyboardInterrupt, Exception) as e:
#     242             run_manager.on_chain_error(e)
# --> 243             raise e
#     244         run_manager.on_chain_end(outputs)
#     245         final_outputs: Dict[str, Any] = self.prep_outputs(
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     235         try:
#     236             outputs = (
# --> 237                 self._call(inputs, run_manager=run_manager)
#     238                 if new_arg_supported
#     239                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#      90         run_manager: Optional[CallbackManagerForChainRun] = None,
#      91     ) -> Dict[str, str]:
# ---> 92         response = self.generate([inputs], run_manager=run_manager)
#      93         return self.create_outputs(response)[0]
#      94
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     100         """Generate LLM result from inputs."""
#     101         prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# --> 102         return self.llm.generate_prompt(
#     103             prompts,
#     104             stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     184     ) -> LLMResult:
#     185         prompt_strings = [p.to_string() for p in prompts]
# --> 186         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     187
#     188     async def agenerate_prompt(
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in generate(self, prompts, stop, callbacks, tags, metadata, **kwargs)
#     277                 dumpd(self), prompts, invocation_params=params, options=options
#     278             )
# --> 279             output = self._generate_helper(
#     280                 prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     281             )
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     221             for run_manager in run_managers:
#     222                 run_manager.on_llm_error(e)
# --> 223             raise e
#     224         flattened_outputs = output.flatten()
#     225         for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     208         try:
#     209             output = (
# --> 210                 self._generate(
#     211                     prompts,
#     212                     stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in _generate(self, prompts, stop, run_manager, **kwargs)
#     600         for prompt in prompts:
#     601             text = (
# --> 602                 self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#     603                 if new_arg_supported
#     604                 else self._call(prompt, stop=stop, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/vertexai.py in _call(self, prompt, stop, run_manager, **kwargs)
#     212             The string generated by the model.
#     213         """
# --> 214         return self._predict(prompt, stop, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/vertexai.py in _predict(self, prompt, stop, **kwargs)
#     114     ) -> str:
#     115         params = {**self._default_params, **kwargs}
# --> 116         res = completion_with_retry(self, prompt, **params)  # type: ignore
#     117         return self._enforce_stop_words(res.text, stop)
#     118
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/vertexai.py in completion_with_retry(llm, *args, **kwargs)
#      57         return llm.client.predict(*args, **kwargs)
#      58
# ---> 59     return _completion_with_retry(*args, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     287         @functools.wraps(f)
#     288         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289             return self(f, *args, **kw)
#     290
#     291         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     377         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378         while True:
# --> 379             do = self.iter(retry_state=retry_state)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     312         is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313         if not (is_explicit_retry or self.retry(retry_state)):
# --> 314             return fut.result()
#     315
#     316         if self.after is not None:
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     449                     raise CancelledError()
#     450                 elif self._state == FINISHED:
# --> 451                     return self.__get_result()
#     452
#     453                 self._condition.wait(timeout)
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
# --> 382                     result = fn(*args, **kwargs)
#     383                 except BaseException:  # noqa: B902
#     384                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/vertexai.py in _completion_with_retry(*args, **kwargs)
#      55     @retry_decorator
#      56     def _completion_with_retry(*args: Any, **kwargs: Any) -> Any:
# ---> 57         return llm.client.predict(*args, **kwargs)
#      58
#      59     return _completion_with_retry(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/vertexai/language_models/_language_models.py in predict(self, prompt, max_output_tokens, temperature, top_k, top_p)
#     261         """
#     262
# --> 263         return self._batch_predict(
#     264             prompts=[prompt],
#     265             max_output_tokens=max_output_tokens,
#
# /usr/local/lib/python3.10/dist-packages/vertexai/language_models/_language_models.py in _batch_predict(self, prompts, max_output_tokens, temperature, top_k, top_p)
#     297         }
#     298
# --> 299         prediction_response = self._endpoint.predict(
#     300             instances=instances,
#     301             parameters=prediction_parameters,
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/models.py in predict(self, instances, parameters, timeout, use_raw_predict)
#    1557             )
#    1558         else:
# -> 1559             prediction_response = self._prediction_client.predict(
#    1560                 endpoint=self._gca_resource.name,
#    1561                 instances=instances,
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform_v1/services/prediction_service/client.py in predict(self, request, endpoint, instances, parameters, retry, timeout, metadata)
#     600
#     601         # Send the request.
# --> 602         response = rpc(
#     603             request,
#     604             retry=retry,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, *args, **kwargs)
#     111             kwargs["metadata"] = metadata
#     112
# --> 113         return wrapped_func(*args, **kwargs)
#     114
#     115
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      72             return callable_(*args, **kwargs)
#      73         except grpc.RpcError as exc:
# ---> 74             raise exceptions.from_grpc_error(exc) from exc
#      75
#      76     return error_remapped_callable
#
# InvalidArgument: 400 Request contains an invalid argument.

# %% [markdown]
# **Summarize: Map Reduce**

# %%
chain = load_summarize_chain(llm, chain_type="map_reduce", verbose=True)

# %%
chain.run(sm_doc)
# Out:
# > Entering new MapReduceDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Write a concise summary of the following:
#
#
# "{"payload":{"allShortcutsEnabled":false,"fileTree":{"data":{"items":[{"name":"large_text_named_worked.txt","path":"data/large_text_named_worked.txt","contentType":"file"},{"name":"small_text_named_muir_lake_tahoe_in_winter.txt","path":"data/small_text_named_muir_lake_tahoe_in_winter.txt","contentType":"file"},{"name":"test.txt","path":"data/test.txt","contentType":"file"}],"totalCount":3},"":{"items":[{"name":"data","path":"data","contentType":"directory"},{"name":"LICENSE","path":"LICENSE","contentType":"file"},{"name":"README.md","path":"README.md","contentType":"file"}],"totalCount":3}},"fileTreeProcessingTime":2.9682720000000002,"foldersToFetch":[],"reducedMotionEnabled":null,"repo":{"id":666981890,"defaultBranch":"main","name":"langchain_MR_with_GCP_genai","ownerLogin":"fangtailin","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"2023-07-16T08:36:54.000Z","ownerAvatar":"https://avatars.githubusercontent.com/u/38515542?v=4","public":true,"private":false,"isOrgOwned":false},"refInfo":{"name":"main","listCacheKey":"v0:1689497119.0","canEdit":false,"refType":"branch","currentOid":"211b4e147268d1e756fe4fbb77d66d60bc55d6cd"},"path":"data/small_text_named_muir_lake_tahoe_in_winter.txt","currentUser":null,"blob":{"rawLines":["The winter glory of the Sierra ! How little is known of it!
#
# Californians admire descriptions of the Swiss Alps, reading with breathless interest how ice and snow load their sublime heights, and booming avalanches sweep in glorious array through their crowded forests, while our own icy, snow-laden mountains, with their unrivaled forests, loom unnoticed along our eastern horizon. True, only mountaineers may penetrate their snow-blocked fastnesses to behold them in all their white wild grandeur, but to every healthy man and woman, and even to children, many of the subalpine valleys and lake-basins, six or seven thousand feet above the sea, remain invitingly open and approachable all winter. With a friend and his two little sons I have just returned from a week of bracing weathering around Lake Tahoe, in which we enjoyed glorious views of winter, fine rolling and sliding in the snow, swimming in the icy lake, and lusty reviving exercise on snow-shoes that kept our pulses dancing right merrily. All the weather was hearty and exhilarating, though varying almost from hour to hour: snowing, blowing, clear and cloudy, but never rigorously cold. ","","This winter has been remarkably mild, the mercury having seldom made a very near approach to zero, even during the coldest nights around the lake, while the average noonday temperature was considerably above the freezing- point.
#
# The snow lies deep on the surrounding mountains and about the shores, solid white contrasting with the dark-blue water of the lake, while the forests and canons and the upper glacial fountain hollows are well filled, assuring abundance of summer water for the lakes and streams. ","","According to the record kept by Mr. McKinney, on the west shore of the lake, eight miles above Tahoe City, at an elevation of 6,500 feet above sea-level, the amount of snow, measured as it fell, was twenty-two feet and four inches for the season up to March 20th, with four inches of rain, while an inch or two more of rain and two or three feet of snow will probably fall before the full opening of spring. Last season the snowfall, measured by the same observer, at the same station, was only nine feet and seven inches, while the season before last it was no less than forty seven feet and six inches. The fall about Yosemite Valley, according to my own observations, usually considerably exceeded this.
#
# The greater portion of the snow that loads the main summits of the range falls in small crisp flakes and broken crystals; or when accompanied by strong winds at a low temperature, the crystals, instead of being locked together in tufted flakes, are driven against each other and broken into meal and fine dust which darkens the sky like night But down in the forested region, at about the elevation of Lake Tahoe, the greater portion comes gently to the ground, light and feathery, some of the flakes in mild weather being nearly an inch in diameter, and is evenly distributed and kept from drifting to any great extent by Lake Tahoe in Winter. 121 the shelter of the woods. Every tree is loaded with the fairy bloom, bending down the branches, and hushing the singing of the elastic needles. When the storm is over and the sun shines, the dazzling snow at once begins to settle and shift and fall off the trees in miniature avalanches; then the relieved branches spring up and shake themselves dry, and the whole green forest, fed and refreshed, waves and sings again rejoicing. The snow on the ground settles also, and thaws and freezes until it becomes coarsely granulated ice, with all trace of its crystalline snow structure destroyed. This is the present condition of most of the snow on the range. From towards midnight until midday at this time of year a man may walk firmly over the surface, as if on ice, provided the preceding day has been warm and the night frosty.
#
# ","","The forested region up to an elevation of about eight thousand feet is generally clear of snow towards the end of May or middle of June; but now (March 28th) the higher canons are still heavily blocked, and the head tributaries of the rivers flow in dark tunnels beneath the icy mass. As warm summer advances, the roof of compacted snow falls in here and there, leaving magnificent arching bridges where it is strongest, over which one may safely ride a horse. All the upper streams are thus buried and bridged every winter, and are seldom completely opened to the light before the end of June or middle of July. ","","Notwithstanding twenty-two feet of snow has fallen here this season, so greatly has it been melted and compacted, the present average depth at a height of 7,500 feet does not exceed seven feet. The drifts in exposed lake hollows and along the lee sides of bald ridges above the timberline are often fifty feet or more in depth, and many of the latter are grandly adorned with overcurling cornices, beneath which pale blue light shimmers with ineffable beauty. But it is in the fountain cirques of the ancient glaciers, beneath the shadows of the highest peaks, that the heaviest and most enduring deposits are stored up. For there the lavish snowfall on the steep converging slopes is shot down in avalanches during or after' every storm, heaping snow on snow to a depth of a hundred feet, or even more at times.
#
# These treasured banks are never wholly melted, however hot the summer, but with the few lingering glaciers form perennial fountains for the highest tributaries of the rivers. ","","Few even among Californians have any fair conception of the marvelous abundance of glacier lakes hidden in the fastnesses of our mountains. The snow and some of the glaciers make a telling show, even from the distant lowlands; but not a single stream is visible, nor a hollow where one might hope to find a lake. Nevertheless, wild rivers are falling and sounding in every canon, and all their upper branches are fairly laden with lakes like orchard-trees with fruit. They nestle in rocky nooks and hollows about all the high peaks and in the larger canons, reflecting their stern, rugged beauty and giving charming animation to the bleakest and most forbidding landscapes. From the summit of Red Mountain, a day's journey to the east of Yosemite Valley, forty-two may be seen within a radius of eight or ten miles. The whole number in the Sierra can hardly be less than fifteen hundred, exclusive of the smaller gems, which are innumerable. Perhaps two-thirds of them lie on the west flank of the range, and all are restricted to the alpine and subalpine regions, those which once brightened the lower regions having long since vanished by the filling in of their basins. Lake Tahoe is king of them all, not only in size, but in the surpassing beauty of its shores and waters.
#
# It seems a kind of heaven to which the dead lakes of the lowlands had come with their best beauty spiritualized. It lies embosomed in mountains of moderate height near the northern extremity of the high portion of the Lake Tahoe in Winter. 123 range, between the main axis and a spur that puts out on the east side from near the head of the Carson River. Though it is twenty-one miles long by ten wide, and from about five hundred to sixteen hundred feet deep, its basin was once occupied by a glacier which filled it from the bottom to a point high above the present water-level, and being lavishly fed by the snows of the encompassing mountains, crawled slowly, like a mighty river, over the north rim of the basin, crushing and grinding the lower mountains that lay in its way, and it was only at the end of the ice period that this noble lake, at least in anything like its present form, came into existence. ","","Excepting the forests that have sprung up around its shores, the post-glacial changes that have taken place are scarcely appreciable. The sediments carried forward by the inflowing streams at the head of the lake have made a few square miles of meadow-land, and the breaking through of a moraine dam in the canon of the outlet has lowered the lake considerably, leaving shore benches and lines on the rocky promontories to mark the original level.
#
# With these comparatively unimportant exceptions, the lake itself and all its grandly sculptured, ice-scored, and moraine-streaked basin exist to-day in just about the condition they presented when first they came to the light towards the close of the Glacial Period. ","","The destructive action of man in clearing away the forests has not as yet effected any very marked change in general views. Perhaps about 150,000,000 feet of lumber for the Comstock mines has thus far been cut from the lake shores. But the business is being pushed so fervently from year to year, almost the entire basin must be stripped ere long of one of its most attractive features. One of the lumber companies at work here has contracted with mine owners to supply 36,000,000 feet of lumber and 60,000 cords of wood this season. It is estimated that the Tahoe basin still contains about 600,000,000 feet of lumber available for the mines. ","","In summer the woods resound with the outlandish noise of loggers and choppers and screaming mills; skiffs and steamboats skim the lovely blue water in work and play; and ever and anon as you thread the groves along shore you come upon groups of gay tourists sauntering about, gathering flowers, or resting luxuriously in the rosiny shade of the pines, some in easy picnic attire, others all ribbons and colors, glaring wildly amid the green leaves and frightening the wondering squirrels and birds. But winter brings rest.
#
# At sight of the first snowflake pleasure-seekers flee as from a plague, the ax leaves the woods, and the kind snow heals every scar. Contemplating the basin from any commanding hilltop, only pale curls of smoke seen at wide intervals betoken the existence of human dwellings. Like the bears, the few settlers that remain here are silently \"holed up.\" The snow covers their cabins as if they were bowlders, and when approached only a narrow shoveled-out passage, or tunnel, is found leading to the door. Some of the more enterprising winter dwellers drift about in boats in calm weather, catching trout for the Carson market,â€”for the lake, on account of its great depth, never freezes. They thus earn from thirty to forty dollars a month, and at the same time get rid of lonely dullness. A trapper may also be seen now and then shuffling along the shore on long Norwegian snow-shoes in pursuit of minks, fishers, and otters. ","","In this letter I intended only to say a good word for winter in the mountains, hoping to incite others to come and enjoy it, sketching our excursion to illustrate the ease and comfort with which such snowy winter rambles may be made; but I have written too much I fear about the snow to leave room for more than a thin outline. We went by rail to Lake Tahoe in Winter. 125 Carson, and from there set out by stage for Glenbrook.
#
# After ascending on wheels until we reached the snow-line, the driver attached his four horses to a sled, hoping thus to cross the summit, which is less than eight thousand feet high, without much difficulty. But mild weather had softened the snow, and the unfortunate animals, after floundering and wallowing through a mile of it, lay down exhausted with their heels in the air. Then we made our way on foot over to the lake. Next day, on a small steam-tug, we crossed the lake to McKinney's, on the west shore, where we were at home. Here we spent a few health-giving, delightful days, rowing, bathing, racing at lightning speed on snow-shoes down a mountain-side back of the house, and slipping about through the solemn, silent woods. Only the eldest of my companions ventured with me on the steep slopes. This was his first experience on snowshoes, and the several descents he made were the most remarkable specimens of falling locomotion that I ever had the fortune to witness. In shooting down steep declivities the long sled-runner-like shoes have to be kept parallel with firmly braced limbs. My friend, however, heedless of advice, launched himself in wild abandon, bouncing and diving, his limbs and shoes in chaotic entanglement, now in the snow, now in the air, whirling over and over in giddy rolls and somersaults that would shame the most extravagant performances of a circus acrobat. How original and inimitable he was!
#
# "],"stylingDirectives":[[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[]],"csv":null,"csvError":null,"dependabotInfo":{"showConfigurationBanner":false,"configFilePath":null,"networkDependabotPath":"/fangtailin/langchain_MR_with_GCP_genai/network/updates","dismissConfigurationNoticePath":"/settings/dismiss-notice/dependabot_configuration_notice","configurationNoticeDismissed":null,"repoAlertsPath":"/fangtailin/langchain_MR_with_GCP_genai/security/dependabot","repoSecurityAndAnalysisPath":"/fangtailin/langchain_MR_with_GCP_genai/settings/security_analysis","repoOwnerIsOrg":false,"currentUserCanAdminRepo":false},"displayName":"small_text_named_muir_lake_tahoe_in_winter.txt","displayUrl":"https://github.com/fangtailin/langchain_MR_with_GCP_genai/blob/main/data/small_text_named_muir_lake_tahoe_in_winter.txt?raw=true","headerInfo":{"blobSize":"13 KB","deleteInfo":{"deletePath":null,"deleteTooltip":"You must be signed in to make or propose changes"},"editInfo":{"editTooltip":"You must be signed in to make or propose changes"},"ghDesktopPath":"https://desktop.github.com","gitLfsPath":null,"onBranch":true,"shortPath":"1586a80","siteNavLoginPath":"/login?return_to=https%3A%2F%2Fgithub.com%2Ffangtailin%2Flangchain_MR_with_GCP_genai%2Fblob%2Fmain%2Fdata%2Fsmall_text_named_muir_lake_tahoe_in_winter.txt","isCSV":false,"isRichtext":false,"toc":null,"lineInfo":{"truncatedLoc":"21","truncatedSloc":"11"},"mode":"file"},"image":false,"isCodeownersFile":null,"isValidLegacyIssueTemp
#
# late":false,"issueTemplateHelpUrl":"https://docs.github.com/articles/about-issue-and-pull-request-templates","issueTemplate":null,"discussionTemplate":null,"language":"Text","large":false,"loggedIn":false,"newDiscussionPath":"/fangtailin/langchain_MR_with_GCP_genai/discussions/new","newIssuePath":"/fangtailin/langchain_MR_with_GCP_genai/issues/new","planSupportInfo":{"repoIsFork":null,"repoOwnedByCurrentUser":null,"requestFullPath":"/fangtailin/langchain_MR_with_GCP_genai/blob/main/data/small_text_named_muir_lake_tahoe_in_winter.txt","showFreeOrgGatedFeatureMessage":null,"showPlanSupportBanner":null,"upgradeDataAttributes":null,"upgradePath":null},"publishBannersInfo":{"dismissActionNoticePath":"/settings/dismiss-notice/publish_action_from_dockerfile","dismissStackNoticePath":"/settings/dismiss-notice/publish_stack_from_file","releasePath":"/fangtailin/langchain_MR_with_GCP_genai/releases/new?marketplace=true","showPublishActionBanner":false,"showPublishStackBanner":false},"renderImageOrRaw":false,"richText":null,"renderedFileInfo":null,"tabSize":8,"topBannersInfo":{"overridingGlobalFundingFile":false,"globalPreferredFundingPath":null,"repoOwner":"fangtailin","repoName":"langchain_MR_with_GCP_genai","showInvalidCitationWarning":false,"citationHelpUrl":"https://docs.github.com/en/github/creating-cloning-and-archiving-repositories/creating-a-repository-on-github/about-citation-files","showDependabotConfigurationBanner":false,"actionsOnboardingTip":null},"truncated":false,"viewa
#
# ble":true,"workflowRedirectUrl":null,"symbols":{"timedOut":false,"notAnalyzed":true,"symbols":[]}},"copilotUserAccess":null,"csrf_tokens":{"/fangtailin/langchain_MR_with_GCP_genai/branches":{"post":"GmonOphRRdBfEz-R0utnBMOSQw3mzBJOcSmDmabN3U6TYCUcNPtcUUGNK1BSSicQfM6zYvQyWxvqGJY4_7W8IQ"}}},"title":"langchain_MR_with_GCP_genai/data/small_text_named_muir_lake_tahoe_in_winter.txt at main · fangtailin/langchain_MR_with_GCP_genai","locale":"en"}
#
# Wonderfully refreshing and exhilarating his queer capers must have been; for on coming to rest, with his runaway members divorced and lost, he would quietly gather himself, pick out the snow from his neck and ears, and say with preternatural solemnity, \"This, Muir, is the very poetry of motion.\"","","We also spent some rare evenings by the huge fire in McKinney's old cabin. The log walls are covered with trophies of the chase, for our host has been a great hunter in his day. Two live pet coons were frolicking on the floor while our grand old host smiled benignly and played with them, the firelight gleaming on his weathered face. How big he seems, thus brought into relief, and what a shadow he casts! The fragrant rosiny fire is the very god of the home. No wonder the old nations, with their fresher instincts, had their fireside gods. At last, when a mild snow-storm was blowing, we rowed to the lower end of the lake and completed our excursion by slipping on snow-shoes down the Truckee canon to the railroad."
#
#
# CONCISE SUMMARY:
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Write a concise summary of the following:
#
#
# "John Muir describes his trip to Lake Tahoe in winter. He writes about the beauty of the snow-covered mountains and lakes, and the fun he had snowshoeing and swimming in the icy lake. He also describes the wildlife he saw, including a bear and two pet coons."
#
#
# CONCISE SUMMARY:
#
# > Finished chain.
#
# > Finished chain.
# 'John Muir describes his trip to Lake Tahoe in winter, writing about the beauty of the snow-covered mountains and lakes, the fun he had snowshoeing and swimming in the icy lake, and the wildlife he saw.'

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size = 8000, # Need to change based on your requirements
    chunk_overlap = 0
)

# %%
lg_docs = text_splitter.split_documents(lg_doc)

# %%
doc_summary(lg_docs)
# Out:
# You have 13 document(s)
# You have roughly 12568 words in your docs
#
# Preview:
# {"payload":{"allShortcutsEnabled":false,"fileTree":{"data":{"items":[{"name":"large_text_named_worked.txt","path":"data/large_text_named_worked.txt","contentType":"file"},{"name":"small_text_named_muir_lake_tahoe_in_winter.txt","path":"data/small_text_named_muir_lake_tahoe_in_winter.txt","contentType":"file"},{"name":"test.txt","path":"data/test.txt","contentType":"file"}],"totalCount":3},"":{"items":[{"name":"data","path":"data","contentType":"directory"},{"name":"LICENSE","path":"LICENSE","contentType":"file"},{"name":"README.md","path":"README.md","contentType":"file"}],"totalCount":3}},"fileTreeProcessingTime":4.1075859999999995,"foldersToFetch":[],"reducedMotionEnabled":null,"repo":{"id":666981890,"defaultBranch":"main","name":"langchain_MR_with_GCP_genai","ownerLogin":"fangtailin","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"2023-07-16T08:36:54.000Z","ownerAvatar":"https://avatars.githubusercontent.com/u/38515542?v=4","public":true,"private":false,"isOrgOwned":false},"refInfo":{"name":"main","listCacheKey":"v0:1689497119.0","canEdit":false,"refType":"branch","currentOid":"211b4e147268d1e756fe4fbb77d66d60bc55d6cd"},"path":"data/large_text_named_worked.txt","currentUser":null,"blob":{"rawLines":["February 2021Before college the two main things I worked on, outside of school,\r","were writing and programming

# %% [markdown]
# Here only 6 splits are used to show the effect of the map reduce, and it's also the same for "refine"

# %%
chain.run(lg_docs[:6])
# Out:
# > Entering new RefineDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Write a concise summary of the following:
#
#
# "{"payload":{"allShortcutsEnabled":false,"fileTree":{"data":{"items":[{"name":"large_text_named_worked.txt","path":"data/large_text_named_worked.txt","contentType":"file"},{"name":"small_text_named_muir_lake_tahoe_in_winter.txt","path":"data/small_text_named_muir_lake_tahoe_in_winter.txt","contentType":"file"},{"name":"test.txt","path":"data/test.txt","contentType":"file"}],"totalCount":3},"":{"items":[{"name":"data","path":"data","contentType":"directory"},{"name":"LICENSE","path":"LICENSE","contentType":"file"},{"name":"README.md","path":"README.md","contentType":"file"}],"totalCount":3}},"fileTreeProcessingTime":4.1075859999999995,"foldersToFetch":[],"reducedMotionEnabled":null,"repo":{"id":666981890,"defaultBranch":"main","name":"langchain_MR_with_GCP_genai","ownerLogin":"fangtailin","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"2023-07-16T08:36:54.000Z","ownerAvatar":"https://avatars.githubusercontent.com/u/38515542?v=4","public":true,"private":false,"isOrgOwned":false},"refInfo":{"name":"main","listCacheKey":"v0:1689497119.0","canEdit":false,"refType":"branch","currentOid":"211b4e147268d1e756fe4fbb77d66d60bc55d6cd"},"path":"data/large_text_named_worked.txt","currentUser":null,"blob":{"rawLines":["February 2021Before college the two main things I worked on, outside of school,\r","were writing and programming. I didn't write essays. I wrote what\r","beginning writers were supposed to write then, and probably still\r","are: short stories.
#
# My stories were awful. They had hardly any plot,\r","just characters with strong feelings, which I imagined made them\r","deep.The first programs I tried writing were on the IBM 1401 that our\r","school district used for what was then called \"data processing.\"\r","This was in 9th grade, so I was 13 or 14. The school district's\r","1401 happened to be in the basement of our junior high school, and\r","my friend Rich Draves and I got permission to use it. It was like\r","a mini Bond villain's lair down there, with all these alien-looking\r","machines  CPU, disk drives, printer, card reader  sitting up\r","on a raised floor under bright fluorescent lights.The language we used was an early version of Fortran. You had to\r","type programs on punch cards, then stack them in the card reader\r","and press a button to load the program into memory and run it. The\r","result would ordinarily be to print something on the spectacularly\r","loud printer.I was puzzled by the 1401. I couldn't figure out what to do with\r","it. And in retrospect there's not much I could have done with it.\r","The only form of input to programs was data stored on punched cards,\r","and I didn't have any data stored on punched cards. The only other\r","option was to do things that didn't rely on any input, like calculate\r","approximations of pi, but I didn't know enough math to do anything\r","interesting of that type.
#
# So I'm not surprised I can't remember any\r","programs I wrote, because they can't have done much. My clearest\r","memory is of the moment I learned it was possible for programs not\r","to terminate, when one of mine didn't. On a machine without\r","time-sharing, this was a social as well as a technical error, as\r","the data center manager's expression made clear.With microcomputers, everything changed. Now you could have a\r","computer sitting right in front of you, on a desk, that could respond\r","to your keystrokes as it was running instead of just churning through\r","a stack of punch cards and then stopping. \r","[1]The first of my friends to get a microcomputer built it himself.\r","It was sold as a kit by Heathkit. I remember vividly how impressed\r","and envious I felt watching him sitting in front of it, typing\r","programs right into the computer.Computers were expensive in those days and it took me years of\r","nagging before I convinced my father to buy one, a TRS-80, in about\r","1980. The gold standard then was the Apple II, but a TRS-80 was\r","good enough. This was when I really started programming. I wrote\r","simple games, a program to predict how high my model rockets would\r","fly, and a word processor that my father used to write at least one\r","book.
#
# There was only room in memory for about 2 pages of text, so\r","he'd write 2 pages at a time and then print them out, but it was a\r","lot better than a typewriter.Though I liked programming, I didn't plan to study it in college.\r","In college I was going to study philosophy, which sounded much more\r","powerful. It seemed, to my naive high school self, to be the study\r","of the ultimate truths, compared to which the things studied in\r","other fields would be mere domain knowledge. What I discovered when\r","I got to college was that the other fields took up so much of the\r","space of ideas that there wasn't much left for these supposed\r","ultimate truths. All that seemed left for philosophy were edge cases\r","that people in other fields felt could safely be ignored.I couldn't have put this into words when I was 18. All I knew at\r","the time was that I kept taking philosophy courses and they kept\r","being boring. So I decided to switch to AI.AI was in the air in the mid 1980s, but there were two things\r","especially that made me want to work on it: a novel by Heinlein\r","called The Moon is a Harsh Mistress, which featured an intelligent\r","computer called Mike, and a PBS documentary that showed Terry\r","Winograd using SHRDLU. I haven't tried rereading The Moon is a Harsh\r","Mistress, so I don't know how well it has aged, but when I read it\r","I was drawn entirely into its world.
#
# It seemed only a matter of\r","time before we'd have Mike, and when I saw Winograd using SHRDLU,\r","it seemed like that time would be a few years at most. All you had\r","to do was teach SHRDLU more words.There weren't any classes in AI at Cornell then, not even graduate\r","classes, so I started trying to teach myself. Which meant learning\r","Lisp, since in those days Lisp was regarded as the language of AI.\r","The commonly used programming languages then were pretty primitive,\r","and programmers' ideas correspondingly so. The default language at\r","Cornell was a Pascal-like language called PL/I, and the situation\r","was similar elsewhere. Learning Lisp expanded my concept of a program\r","so fast that it was years before I started to have a sense of where\r","the new limits were. This was more like it; this was what I had\r","expected college to do. It wasn't happening in a class, like it was\r","supposed to, but that was ok. For the next couple years I was on a\r","roll. I knew what I was going to do.For my undergraduate thesis, I reverse-engineered SHRDLU. My God\r","did I love working on that program. It was a pleasing bit of code,\r","but what made it even more exciting was my belief  hard to imagine\r","now, but not unique in 1985  that it was already climbing the\r","lower slopes of intelligence.I had gotten into a program at Cornell that didn't make you choose\r","a major."
#
#
# CONCISE SUMMARY:
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary
# We have provided an existing summary up to a certain point: The author's early interest in programming and AI led him to study computer science in college. He was particularly inspired by the works of Heinlein and Winograd, and he learned Lisp to teach himself AI. He wrote his undergraduate thesis on SHRDLU, and he believes that it was already climbing the lower slopes of intelligence.
# We have the opportunity to refine the existing summary(only if needed) with some more context below.
# ------------
# You could take whatever classes you liked, and choose\r","whatever you liked to put on your degree. I of course chose \"Artificial\r","Intelligence.\" When I got the actual physical diploma, I was dismayed\r","to find that the quotes had been included, which made them read as\r","scare-quotes. At the time this bothered me, but now it seems amusingly\r","accurate, for reasons I was about to discover.I applied to 3 grad schools: MIT and Yale, which were renowned for\r","AI at the time, and Harvard, which I'd visited because Rich Draves\r","went there, and was also home to Bill Woods, who'd invented the\r","type of parser I used in my SHRDLU clone. Only Harvard accepted me,\r","so that was where I went.I don't remember the moment it happened, or if there even was a\r","specific moment, but during the first year of grad school I realized\r","that AI, as practiced at the time, was a hoax. By which I mean the\r","sort of AI in which a program that's told \"the dog is sitting on\r","the chair\" translates this into some formal representation and adds\r","it to the list of things it knows.What these programs really showed was that there's a subset of\r","natural language that's a formal language. But a very proper subset.\r","It was clear that there was an unbridgeable gap between what they\r","could do and actually understanding natural language. It was not,\r","in fact, simply a matter of teaching SHRDLU more words.
#
# That whole\r","way of doing AI, with explicit data structures representing concepts,\r","was not going to work. Its brokenness did, as so often happens,\r","generate a lot of opportunities to write papers about various\r","band-aids that could be applied to it, but it was never going to\r","get us Mike.So I looked around to see what I could salvage from the wreckage\r","of my plans, and there was Lisp. I knew from experience that Lisp\r","was interesting for its own sake and not just for its association\r","with AI, even though that was the main reason people cared about\r","it at the time. So I decided to focus on Lisp. In fact, I decided\r","to write a book about Lisp hacking. It's scary to think how little\r","I knew about Lisp hacking when I started writing that book. But\r","there's nothing like writing a book about something to help you\r","learn it. The book, On Lisp, wasn't published till 1993, but I wrote\r","much of it in grad school.Computer Science is an uneasy alliance between two halves, theory\r","and systems. The theory people prove things, and the systems people\r","build things. I wanted to build things. I had plenty of respect for\r","theory  indeed, a sneaking suspicion that it was the more admirable\r","of the two halves  but building things seemed so much more exciting.The problem with systems work, though, was that it didn't last.\r","Any program you wrote today, no matter how good, would be obsolete\r","in a couple decades at best.
#
# People might mention your software in\r","footnotes, but no one would actually use it. And indeed, it would\r","seem very feeble work. Only people with a sense of the history of\r","the field would even realize that, in its time, it had been good.There were some surplus Xerox Dandelions floating around the computer\r","lab at one point. Anyone who wanted one to play around with could\r","have one. I was briefly tempted, but they were so slow by present\r","standards; what was the point? No one else wanted one either, so\r","off they went. That was what happened to systems work.I wanted not just to build things, but to build things that would\r","last.In this dissatisfied state I went in 1988 to visit Rich Draves at\r","CMU, where he was in grad school. One day I went to visit the\r","Carnegie Institute, where I'd spent a lot of time as a kid. While\r","looking at a painting there I realized something that might seem\r","obvious, but was a big surprise to me. There, right on the wall,\r","was something you could make that would last. Paintings didn't\r","become obsolete. Some of the best ones were hundreds of years old.And moreover this was something you could make a living doing. Not\r","as easily as you could by writing software, of course, but I thought\r","if you were really industrious and lived really cheaply, it had to\r","be possible to make enough to survive. And as an artist you could\r","be truly independent.
#
# You wouldn't have a boss, or even need to get\r","research funding.I had always liked looking at paintings. Could I make them? I had\r","no idea. I'd never imagined it was even possible. I knew intellectually\r","that people made art  that it didn't just appear spontaneously\r"," but it was as if the people who made it were a different species.\r","They either lived long ago or were mysterious geniuses doing strange\r","things in profiles in Life magazine. The idea of actually being\r","able to make art, to put that verb before that noun, seemed almost\r","miraculous.That fall I started taking art classes at Harvard. Grad students\r","could take classes in any department, and my advisor, Tom Cheatham,\r","was very easy going. If he even knew about the strange classes I\r","was taking, he never said anything.So now I was in a PhD program in computer science, yet planning to\r","be an artist, yet also genuinely in love with Lisp hacking and\r","working away at On Lisp. In other words, like many a grad student,\r","I was working energetically on multiple projects that were not my\r","thesis.I didn't see a way out of this situation. I didn't want to drop out\r","of grad school, but how else was I going to get out? I remember\r","when my friend Robert Morris got kicked out of Cornell for writing\r","the internet worm of 1988, I was envious that he'd found such a\r","spectacular way to get out of grad school.Then one day in April 1990 a crack appeared in the wall.
#
# I ran into\r","professor Cheatham and he asked if I was far enough along to graduate\r","that June. I didn't have a word of my dissertation written, but in\r","what must have been the quickest bit of thinking in my life, I\r","decided to take a shot at writing one in the 5 weeks or so that\r","remained before the deadline, reusing parts of On Lisp where I\r","could, and I was able to respond, with no perceptible delay \"Yes,\r","I think so. I'll give you something to read in a few days.\"I picked applications of continuations as the topic. In retrospect\r","I should have written about macros and embedded languages. There's\r","a whole world there that's barely been explored. But all I wanted\r","was to get out of grad school, and my rapidly written dissertation\r","sufficed, just barely.Meanwhile I was applying to art schools. I applied to two: RISD in\r","the US, and the Accademia di Belli Arti in Florence, which, because\r","it was the oldest art school, I imagined would be good. RISD accepted\r","me, and I never heard back from the Accademia, so off to Providence\r","I went.I'd applied for the BFA program at RISD, which meant in effect that\r","I had to go to college again. This was not as strange as it sounds,\r","because I was only 25, and art schools are full of people of different\r","ages. RISD counted me as a transfer sophomore and said I had to do\r","the foundation that summer.
# ------------
# Given the new context, refine the original summary
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary
# We have provided an existing summary up to a certain point: The author's early interest in programming and AI led him to study computer science in college. He was particularly inspired by the works of Heinlein and Winograd, and he learned Lisp to teach himself AI. He wrote his undergraduate thesis on SHRDLU, and he believes that it was already climbing the lower slopes of intelligence.
#
# He applied to 3 grad schools: MIT, Yale, and Harvard. Only Harvard accepted him, so that was where he went. During his first year of grad school, he realized that AI, as practiced at the time, was a hoax. He decided to focus on Lisp and write a
# We have the opportunity to refine the existing summary(only if needed) with some more context below.
# ------------
# The foundation means the classes that\r","everyone has to take in fundamental subjects like drawing, color,\r","and design.Toward the end of the summer I got a big surprise: a letter from\r","the Accademia, which had been delayed because they'd sent it to\r","Cambridge England instead of Cambridge Massachusetts, inviting me\r","to take the entrance exam in Florence that fall. This was now only\r","weeks away. My nice landlady let me leave my stuff in her attic. I\r","had some money saved from consulting work I'd done in grad school;\r","there was probably enough to last a year if I lived cheaply. Now\r","all I had to do was learn Italian.Only stranieri (foreigners) had to take this entrance exam. In\r","retrospect it may well have been a way of excluding them, because\r","there were so many stranieri attracted by the idea of studying\r","art in Florence that the Italian students would otherwise have been\r","outnumbered. I was in decent shape at painting and drawing from the\r","RISD foundation that summer, but I still don't know how I managed\r","to pass the written exam. I remember that I answered the essay\r","question by writing about Cezanne, and that I cranked up the\r","intellectual level as high as I could to make the most of my limited\r","vocabulary.
#
# \r","[2]I'm only up to age 25 and already there are such conspicuous patterns.\r","Here I was, yet again about to attend some august institution in\r","the hopes of learning about some prestigious subject, and yet again\r","about to be disappointed. The students and faculty in the painting\r","department at the Accademia were the nicest people you could imagine,\r","but they had long since arrived at an arrangement whereby the\r","students wouldn't require the faculty to teach anything, and in\r","return the faculty wouldn't require the students to learn anything.\r","And at the same time all involved would adhere outwardly to the\r","conventions of a 19th century atelier. We actually had one of those\r","little stoves, fed with kindling, that you see in 19th century\r","studio paintings, and a nude model sitting as close to it as possible\r","without getting burned. Except hardly anyone else painted her besides\r","me. The rest of the students spent their time chatting or occasionally\r","trying to imitate things they'd seen in American art magazines.Our model turned out to live just down the street from me. She made\r","a living from a combination of modelling and making fakes for a\r","local antique dealer. She'd copy an obscure old painting out of a\r","book, and then he'd take the copy and maltreat it to make it look\r","old. \r","[3]While I was a student at the Accademia I started painting still\r","lives in my bedroom at night.
#
# These paintings were tiny, because\r","the room was, and because I painted them on leftover scraps of\r","canvas, which was all I could afford at the time. Painting still\r","lives is different from painting people, because the subject, as\r","its name suggests, can't move. People can't sit for more than about\r","15 minutes at a time, and when they do they don't sit very still.\r","So the traditional m.o. for painting people is to know how to paint\r","a generic person, which you then modify to match the specific person\r","you're painting. Whereas a still life you can, if you want, copy\r","pixel by pixel from what you're seeing. You don't want to stop\r","there, of course, or you get merely photographic accuracy, and what\r","makes a still life interesting is that it's been through a head.\r","You want to emphasize the visual cues that tell you, for example,\r","that the reason the color changes suddenly at a certain point is\r","that it's the edge of an object. By subtly emphasizing such things\r","you can make paintings that are more realistic than photographs not\r","just in some metaphorical sense, but in the strict information-theoretic\r","sense. \r","[4]I liked painting still lives because I was curious about what I was\r","seeing. In everyday life, we aren't consciously aware of much we're\r","seeing.
#
# Most visual perception is handled by low-level processes\r","that merely tell your brain \"that's a water droplet\" without telling\r","you details like where the lightest and darkest points are, or\r","\"that's a bush\" without telling you the shape and position of every\r","leaf. This is a feature of brains, not a bug. In everyday life it\r","would be distracting to notice every leaf on every bush. But when\r","you have to paint something, you have to look more closely, and\r","when you do there's a lot to see. You can still be noticing new\r","things after days of trying to paint something people usually take\r","for granted, just as you can  after\r","days of trying to write an essay about something people usually\r","take for granted.This is not the only way to paint. I'm not 100% sure it's even a\r","good way to paint. But it seemed a good enough bet to be worth\r","trying.Our teacher, professor Ulivi, was a nice guy. He could see I worked\r","hard, and gave me a good grade, which he wrote down in a sort of\r","passport each student had. But the Accademia wasn't teaching me\r","anything except Italian, and my money was running out, so at the\r","end of the first year I went back to the US.I wanted to go back to RISD, but I was now broke and RISD was very\r","expensive, so I decided to get a job for a year and then return to\r","RISD the next fall. I got one at a company called Interleaf, which\r","made software for creating documents.
#
# You mean like Microsoft Word?\r","Exactly. That was how I learned that low end software tends to eat\r","high end software. But Interleaf still had a few years to live yet.\r","[5]Interleaf had done something pretty bold. Inspired by Emacs, they'd\r","added a scripting language, and even made the scripting language a\r","dialect of Lisp. Now they wanted a Lisp hacker to write things in\r","it. This was the closest thing I've had to a normal job, and I\r","hereby apologize to my boss and coworkers, because I was a bad\r","employee. Their Lisp was the thinnest icing on a giant C cake, and\r","since I didn't know C and didn't want to learn it, I never understood\r","most of the software. Plus I was terribly irresponsible. This was\r","back when a programming job meant showing up every day during certain\r","working hours. That seemed unnatural to me, and on this point the\r","rest of the world is coming around to my way of thinking, but at\r","the time it caused a lot of friction. Toward the end of the year I\r","spent much of my time surreptitiously working on On Lisp, which I\r","had by this time gotten a contract to publish.The good part was that I got paid huge amounts of money, especially\r","by art student standards. In Florence, after paying my part of the\r","rent, my budget for everything else had been $7 a day. Now I was\r","getting paid more than 4 times that every hour, even when I was\r","just sitting in a meeting.
# ------------
# Given the new context, refine the original summary
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary
# We have provided an existing summary up to a certain point: The author's early interest in programming and AI led him to study computer science in college. He was particularly inspired by the works of Heinlein and Winograd, and he learned Lisp to teach himself AI. He wrote his undergraduate thesis on SHRDLU, and he believes that it was already climbing the lower slopes of intelligence.
#
# He applied to 3 grad schools: MIT, Yale, and Harvard. Only Harvard accepted him, so that was where he went. During his first year of grad school, he realized that AI, as practiced at the time, was a hoax. He decided to focus on Lisp and write a
# We have the opportunity to refine the existing summary(only if needed) with some more context below.
# ------------
# By living cheaply I not only managed to\r","save enough to go back to RISD, but also paid off my college loans.I learned some useful things at Interleaf, though they were mostly\r","about what not to do. I learned that it's better for technology\r","companies to be run by product people than sales people (though\r","sales is a real skill and people who are good at it are really good\r","at it), that it leads to bugs when code is edited by too many people,\r","that cheap office space is no bargain if it's depressing, that\r","planned meetings are inferior to corridor conversations, that big,\r","bureaucratic customers are a dangerous source of money, and that\r","there's not much overlap between conventional office hours and the\r","optimal time for hacking, or conventional offices and the optimal\r","place for it.But the most important thing I learned, and which I used in both\r","Viaweb and Y Combinator, is that the low end eats the high end:\r","that it's good to be the \"entry level\" option, even though that\r","will be less prestigious, because if you're not, someone else will\r","be, and will squash you against the ceiling. Which in turn means\r","that prestige is a danger sign.When I left to go back to RISD the next fall, I arranged to do\r","freelance work for the group that did projects for customers, and\r","this was how I survived for the next several years.
#
# When I came\r","back to visit for a project later on, someone told me about a new\r","thing called HTML, which was, as he described it, a derivative of\r","SGML. Markup language enthusiasts were an occupational hazard at\r","Interleaf and I ignored him, but this HTML thing later became a big\r","part of my life.In the fall of 1992 I moved back to Providence to continue at RISD.\r","The foundation had merely been intro stuff, and the Accademia had\r","been a (very civilized) joke. Now I was going to see what real art\r","school was like. But alas it was more like the Accademia than not.\r","Better organized, certainly, and a lot more expensive, but it was\r","now becoming clear that art school did not bear the same relationship\r","to art that medical school bore to medicine. At least not the\r","painting department. The textile department, which my next door\r","neighbor belonged to, seemed to be pretty rigorous. No doubt\r","illustration and architecture were too. But painting was post-rigorous.\r","Painting students were supposed to express themselves, which to the\r","more worldly ones meant to try to cook up some sort of distinctive\r","signature style.A signature style is the visual equivalent of what in show business\r","is known as a \"schtick\": something that immediately identifies the\r","work as yours and no one else's. For example, when you see a painting\r","that looks like a certain kind of cartoon, you know it's by Roy\r","Lichtenstein.
#
# So if you see a big painting of this type hanging in\r","the apartment of a hedge fund manager, you know he paid millions\r","of dollars for it. That's not always why artists have a signature\r","style, but it's usually why buyers pay a lot for such work.\r","[6]There were plenty of earnest students too: kids who \"could draw\"\r","in high school, and now had come to what was supposed to be the\r","best art school in the country, to learn to draw even better. They\r","tended to be confused and demoralized by what they found at RISD,\r","but they kept going, because painting was what they did. I was not\r","one of the kids who could draw in high school, but at RISD I was\r","definitely closer to their tribe than the tribe of signature style\r","seekers.I learned a lot in the color class I took at RISD, but otherwise I\r","was basically teaching myself to paint, and I could do that for\r","free. So in 1993 I dropped out. I hung around Providence for a bit,\r","and then my college friend Nancy Parmet did me a big favor. A\r","rent-controlled apartment in a building her mother owned in New\r","York was becoming vacant. Did I want it? It wasn't much more than\r","my current place, and New York was supposed to be where the artists\r","were. So yes, I wanted it!\r","[7]Asterix comics begin by zooming in on a tiny corner of Roman Gaul\r","that turns out not to be controlled by the Romans.
#
# You can do\r","something similar on a map of New York City: if you zoom in on the\r","Upper East Side, there's a tiny corner that's not rich, or at least\r","wasn't in 1993. It's called Yorkville, and that was my new home.\r","Now I was a New York artist  in the strictly technical sense of\r","making paintings and living in New York.I was nervous about money, because I could sense that Interleaf was\r","on the way down. Freelance Lisp hacking work was very rare, and I\r","didn't want to have to program in another language, which in those\r","days would have meant C++ if I was lucky. So with my unerring nose\r","for financial opportunity, I decided to write another book on Lisp.\r","This would be a popular book, the sort of book that could be used\r","as a textbook. I imagined myself living frugally off the royalties\r","and spending all my time painting. (The painting on the cover of\r","this book, ANSI Common Lisp, is one that I painted around this\r","time. )The best thing about New York for me was the presence of Idelle and\r","Julian Weber. Idelle Weber was a painter, one of the early\r","photorealists, and I'd taken her painting class at Harvard. I've\r","never known a teacher more beloved by her students. Large numbers\r","of former students kept in touch with her, including me.
#
# After I\r","moved to New York I became her de facto studio assistant.She liked to paint on big, square canvases, 4 to 5 feet on a side.\r","One day in late 1994 as I was stretching one of these monsters there\r","was something on the radio about a famous fund manager. He wasn't\r","that much older than me, and was super rich. The thought suddenly\r","occurred to me: why don't I become rich? Then I'll be able to work\r","on whatever I want.Meanwhile I'd been hearing more and more about this new thing called\r","the World Wide Web. Robert Morris showed it to me when I visited\r","him in Cambridge, where he was now in grad school at Harvard. It\r","seemed to me that the web would be a big deal. I'd seen what graphical\r","user interfaces had done for the popularity of microcomputers. It\r","seemed like the web would do the same for the internet.If I wanted to get rich, here was the next train leaving the station.\r","I was right about that part. What I got wrong was the idea. I decided\r","we should start a company to put art galleries online. I can't\r","honestly say, after reading so many Y Combinator applications, that\r","this was the worst startup idea ever, but it was up there. Art\r","galleries didn't want to be online, and still don't, not the fancy\r","ones. That's not how they sell. I wrote some software to generate\r","web sites for galleries, and Robert wrote some to resize images and\r","set up an http server to serve the pages.
# ------------
# Given the new context, refine the original summary
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary
# We have provided an existing summary up to a certain point: The author's early interest in programming and AI led him to study computer science in college. He was particularly inspired by the works of Heinlein and Winograd, and he learned Lisp to teach himself AI. He wrote his undergraduate thesis on SHRDLU, and he believes that it was already climbing the lower slopes of intelligence.
#
# He applied to 3 grad schools: MIT, Yale, and Harvard. Only Harvard accepted him, so that was where he went. During his first year of grad school, he realized that AI, as practiced at the time, was a hoax. He decided to focus on Lisp and write a
# We have the opportunity to refine the existing summary(only if needed) with some more context below.
# ------------
# Then we tried to sign up\r","galleries. To call this a difficult sale would be an understatement.\r","It was difficult to give away. A few galleries let us make sites\r","for them for free, but none paid us.Then some online stores started to appear, and I realized that\r","except for the order buttons they were identical to the sites we'd\r","been generating for galleries. This impressive-sounding thing called\r","an \"internet storefront\" was something we already knew how to build.So in the summer of 1995, after I submitted the camera-ready copy\r","of ANSI Common Lisp to the publishers, we started trying to write\r","software to build online stores. At first this was going to be\r","normal desktop software, which in those days meant Windows software.\r","That was an alarming prospect, because neither of us knew how to\r","write Windows software or wanted to learn. We lived in the Unix\r","world. But we decided we'd at least try writing a prototype store\r","builder on Unix. Robert wrote a shopping cart, and I wrote a new\r","site generator for stores  in Lisp, of course.We were working out of Robert's apartment in Cambridge. His roommate\r","was away for big chunks of time, during which I got to sleep in his\r","room. For some reason there was no bed frame or sheets, just a\r","mattress on the floor.
#
# One morning as I was lying on this mattress\r","I had an idea that made me sit up like a capital L. What if we ran\r","the software on the server, and let users control it by clicking\r","on links? Then we'd never have to write anything to run on users'\r","computers. We could generate the sites on the same server we'd serve\r","them from. Users wouldn't need anything more than a browser.This kind of software, known as a web app, is common now, but at\r","the time it wasn't clear that it was even possible. To find out,\r","we decided to try making a version of our store builder that you\r","could control through the browser. A couple days later, on August\r","12, we had one that worked. The UI was horrible, but it proved you\r","could build a whole store through the browser, without any client\r","software or typing anything into the command line on the server.Now we felt like we were really onto something. I had visions of a\r","whole new generation of software working this way. You wouldn't\r","need versions, or ports, or any of that crap. At Interleaf there\r","had been a whole group called Release Engineering that seemed to\r","be at least as big as the group that actually wrote the software.\r","Now you could just update the software right on the server.We started a new company we called Viaweb, after the fact that our\r","software worked via the web, and we got $10,000 in seed funding\r","from Idelle's husband Julian.
#
# In return for that and doing the\r","initial legal work and giving us business advice, we gave him 10%\r","of the company. Ten years later this deal became the model for Y\r","Combinator's. We knew founders needed something like this, because\r","we'd needed it ourselves.At this stage I had a negative net worth, because the thousand\r","dollars or so I had in the bank was more than counterbalanced by\r","what I owed the government in taxes. (Had I diligently set aside\r","the proper proportion of the money I'd made consulting for Interleaf?\r","No, I had not.) So although Robert had his graduate student stipend,\r","I needed that seed funding to live on.We originally hoped to launch in September, but we got more ambitious\r","about the software as we worked on it. Eventually we managed to\r","build a WYSIWYG site builder, in the sense that as you were creating\r","pages, they looked exactly like the static ones that would be\r","generated later, except that instead of leading to static pages,\r","the links all referred to closures stored in a hash table on the\r","server.It helped to have studied art, because the main goal of an online\r","store builder is to make users look legit, and the key to looking\r","legit is high production values. If you get page layouts and fonts\r","and colors right, you can make a guy running a store out of his\r","bedroom look more legit than a big company.
#
# (If you're curious why my site looks so old-fashioned, it's because\r","it's still made with this software. It may look clunky today, but\r","in 1996 it was the last word in slick. )In September, Robert rebelled. \"We've been working on this for a\r","month,\" he said, \"and it's still not done.\" This is funny in\r","retrospect, because he would still be working on it almost 3 years\r","later. But I decided it might be prudent to recruit more programmers,\r","and I asked Robert who else in grad school with him was really good.\r","He recommended Trevor Blackwell, which surprised me at first, because\r","at that point I knew Trevor mainly for his plan to reduce everything\r","in his life to a stack of notecards, which he carried around with\r","him. But Rtm was right, as usual. Trevor turned out to be a\r","frighteningly effective hacker.It was a lot of fun working with Robert and Trevor. They're the two\r","most independent-minded people \r","I know, and in completely different\r","ways. If you could see inside Rtm's brain it would look like a\r","colonial New England church, and if you could see inside Trevor's\r","it would look like the worst excesses of Austrian Rococo.We opened for business, with 6 stores, in January 1996. It was just\r","as well we waited a few months, because although we worried we were\r","late, we were actually almost fatally early.
#
# There was a lot of\r","talk in the press then about ecommerce, but not many people actually\r","wanted online stores.\r","[8]There were three main parts to the software: the editor, which\r","people used to build sites and which I wrote, the shopping cart,\r","which Robert wrote, and the manager, which kept track of orders and\r","statistics, and which Trevor wrote. In its time, the editor was one\r","of the best general-purpose site builders. I kept the code tight\r","and didn't have to integrate with any other software except Robert's\r","and Trevor's, so it was quite fun to work on. If all I'd had to do\r","was work on this software, the next 3 years would have been the\r","easiest of my life. Unfortunately I had to do a lot more, all of\r","it stuff I was worse at than programming, and the next 3 years were\r","instead the most stressful.There were a lot of startups making ecommerce software in the second\r","half of the 90s. We were determined to be the Microsoft Word, not\r","the Interleaf. Which meant being easy to use and inexpensive. It\r","was lucky for us that we were poor, because that caused us to make\r","Viaweb even more inexpensive than we realized. We charged $100 a\r","month for a small store and $300 a month for a big one. This low\r","price was a big attraction, and a constant thorn in the sides of\r","competitors, but it wasn't because of some clever insight that we\r","set the price low.
# ------------
# Given the new context, refine the original summary
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary
# We have provided an existing summary up to a certain point: The author's early interest in programming and AI led him to study computer science in college. He was particularly inspired by the works of Heinlein and Winograd, and he learned Lisp to teach himself AI. He wrote his undergraduate thesis on SHRDLU, and he believes that it was already climbing the lower slopes of intelligence.
#
# He applied to 3 grad schools: MIT, Yale, and Harvard. Only Harvard accepted him, so that was where he went. During his first year of grad school, he realized that AI, as practiced at the time, was a hoax. He decided to focus on Lisp and write a
# We have the opportunity to refine the existing summary(only if needed) with some more context below.
# ------------
# We had no idea what businesses paid for things.\r","$300 a month seemed like a lot of money to us.We did a lot of things right by accident like that. For example,\r","we did what's now called \"doing things that \r","don't scale,\" although\r","at the time we would have described it as \"being so lame that we're\r","driven to the most desperate measures to get users.\" The most common\r","of which was building stores for them. This seemed particularly\r","humiliating, since the whole raison d'etre of our software was that\r","people could use it to make their own stores. But anything to get\r","users.We learned a lot more about retail than we wanted to know. For\r","example, that if you could only have a small image of a man's shirt\r","(and all images were small then by present standards), it was better\r","to have a closeup of the collar than a picture of the whole shirt.\r","The reason I remember learning this was that it meant I had to\r","rescan about 30 images of men's shirts. My first set of scans were\r","so beautiful too.Though this felt wrong, it was exactly the right thing to be doing.\r","Building stores for users taught us about retail, and about how it\r","felt to use our software.
#
# I was initially both mystified and repelled\r","by \"business\" and thought we needed a \"business person\" to be in\r","charge of it, but once we started to get users, I was converted,\r","in much the same way I was converted to \r","fatherhood once I had kids.\r","Whatever users wanted, I was all theirs. Maybe one day we'd have\r","so many users that I couldn't scan their images for them, but in\r","the meantime there was nothing more important to do.Another thing I didn't get at the time is that \r","growth rate is the\r","ultimate test of a startup. Our growth rate was fine. We had about\r","70 stores at the end of 1996 and about 500 at the end of 1997. I\r","mistakenly thought the thing that mattered was the absolute number\r","of users. And that is the thing that matters in the sense that\r","that's how much money you're making, and if you're not making enough,\r","you might go out of business. But in the long term the growth rate\r","takes care of the absolute number. If we'd been a startup I was\r","advising at Y Combinator, I would have said: Stop being so stressed\r","out, because you're doing fine. You're growing 7x a year. Just don't\r","hire too many more people and you'll soon be profitable, and then\r","you'll control your own destiny.Alas I hired lots more people, partly because our investors wanted\r","me to, and partly because that's what startups did during the\r","Internet Bubble. A company with just a handful of employees would\r","have seemed amateurish.
#
# So we didn't reach breakeven until about\r","when Yahoo bought us in the summer of 1998. Which in turn meant we\r","were at the mercy of investors for the entire life of the company.\r","And since both we and our investors were noobs at startups, the\r","result was a mess even by startup standards.It was a huge relief when Yahoo bought us. In principle our Viaweb\r","stock was valuable. It was a share in a business that was profitable\r","and growing rapidly. But it didn't feel very valuable to me; I had\r","no idea how to value a business, but I was all too keenly aware of\r","the near-death experiences we seemed to have every few months. Nor\r","had I changed my grad student lifestyle significantly since we\r","started. So when Yahoo bought us it felt like going from rags to\r","riches. Since we were going to California, I bought a car, a yellow\r","1998 VW GTI. I remember thinking that its leather seats alone were\r","by far the most luxurious thing I owned.The next year, from the summer of 1998 to the summer of 1999, must\r","have been the least productive of my life. I didn't realize it at\r","the time, but I was worn out from the effort and stress of running\r","Viaweb. For a while after I got to California I tried to continue\r","my usual m.o. of programming till 3 in the morning, but fatigue\r","combined with Yahoo's prematurely aged\r","culture and grim cube farm\r","in Santa Clara gradually dragged me down.
#
# After a few months it\r","felt disconcertingly like working at Interleaf.Yahoo had given us a lot of options when they bought us. At the\r","time I thought Yahoo was so overvalued that they'd never be worth\r","anything, but to my astonishment the stock went up 5x in the next\r","year. I hung on till the first chunk of options vested, then in the\r","summer of 1999 I left. It had been so long since I'd painted anything\r","that I'd half forgotten why I was doing this. My brain had been\r","entirely full of software and men's shirts for 4 years. But I had\r","done this to get rich so I could paint, I reminded myself, and now\r","I was rich, so I should go paint.When I said I was leaving, my boss at Yahoo had a long conversation\r","with me about my plans. I told him all about the kinds of pictures\r","I wanted to paint. At the time I was touched that he took such an\r","interest in me. Now I realize it was because he thought I was lying.\r","My options at that point were worth about $2 million a month. If I\r","was leaving that kind of money on the table, it could only be to\r","go and start some new startup, and if I did, I might take people\r","with me. This was the height of the Internet Bubble, and Yahoo was\r","ground zero of it. My boss was at that moment a billionaire.
#
# Leaving\r","then to start a new startup must have seemed to him an insanely,\r","and yet also plausibly, ambitious plan.But I really was quitting to paint, and I started immediately.\r","There was no time to lose. I'd already burned 4 years getting rich.\r","Now when I talk to founders who are leaving after selling their\r","companies, my advice is always the same: take a vacation. That's\r","what I should have done, just gone off somewhere and done nothing\r","for a month or two, but the idea never occurred to me.So I tried to paint, but I just didn't seem to have any energy or\r","ambition. Part of the problem was that I didn't know many people\r","in California. I'd compounded this problem by buying a house up in\r","the Santa Cruz Mountains, with a beautiful view but miles from\r","anywhere. I stuck it out for a few more months, then in desperation\r","I went back to New York, where unless you understand about rent\r","control you'll be surprised to hear I still had my apartment, sealed\r","up like a tomb of my old life. Idelle was in New York at least, and\r","there were other people trying to paint there, even though I didn't\r","know any of them.When I got back to New York I resumed my old life, except now I was\r","rich. It was as weird as it sounds. I resumed all my old patterns,\r","except now there were doors where there hadn't been.
# ------------
# Given the new context, refine the original summary
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
# > Finished chain.
# ''

# %% [markdown]
# **Summarize: Refine**

# %%
chain = load_summarize_chain(llm, chain_type="refine", verbose=True)

# %%
chain.run(lg_docs[:6])
# Out:
# > Entering new RefineDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Write a concise summary of the following:
#
#
# "{"payload":{"allShortcutsEnabled":false,"fileTree":{"data":{"items":[{"name":"large_text_named_worked.txt","path":"data/large_text_named_worked.txt","contentType":"file"},{"name":"small_text_named_muir_lake_tahoe_in_winter.txt","path":"data/small_text_named_muir_lake_tahoe_in_winter.txt","contentType":"file"},{"name":"test.txt","path":"data/test.txt","contentType":"file"}],"totalCount":3},"":{"items":[{"name":"data","path":"data","contentType":"directory"},{"name":"LICENSE","path":"LICENSE","contentType":"file"},{"name":"README.md","path":"README.md","contentType":"file"}],"totalCount":3}},"fileTreeProcessingTime":4.1075859999999995,"foldersToFetch":[],"reducedMotionEnabled":null,"repo":{"id":666981890,"defaultBranch":"main","name":"langchain_MR_with_GCP_genai","ownerLogin":"fangtailin","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"2023-07-16T08:36:54.000Z","ownerAvatar":"https://avatars.githubusercontent.com/u/38515542?v=4","public":true,"private":false,"isOrgOwned":false},"refInfo":{"name":"main","listCacheKey":"v0:1689497119.0","canEdit":false,"refType":"branch","currentOid":"211b4e147268d1e756fe4fbb77d66d60bc55d6cd"},"path":"data/large_text_named_worked.txt","currentUser":null,"blob":{"rawLines":["February 2021Before college the two main things I worked on, outside of school,\r","were writing and programming. I didn't write essays. I wrote what\r","beginning writers were supposed to write then, and probably still\r","are: short stories.
#
# My stories were awful. They had hardly any plot,\r","just characters with strong feelings, which I imagined made them\r","deep.The first programs I tried writing were on the IBM 1401 that our\r","school district used for what was then called \"data processing.\"\r","This was in 9th grade, so I was 13 or 14. The school district's\r","1401 happened to be in the basement of our junior high school, and\r","my friend Rich Draves and I got permission to use it. It was like\r","a mini Bond villain's lair down there, with all these alien-looking\r","machines  CPU, disk drives, printer, card reader  sitting up\r","on a raised floor under bright fluorescent lights.The language we used was an early version of Fortran. You had to\r","type programs on punch cards, then stack them in the card reader\r","and press a button to load the program into memory and run it. The\r","result would ordinarily be to print something on the spectacularly\r","loud printer.I was puzzled by the 1401. I couldn't figure out what to do with\r","it. And in retrospect there's not much I could have done with it.\r","The only form of input to programs was data stored on punched cards,\r","and I didn't have any data stored on punched cards. The only other\r","option was to do things that didn't rely on any input, like calculate\r","approximations of pi, but I didn't know enough math to do anything\r","interesting of that type.
#
# So I'm not surprised I can't remember any\r","programs I wrote, because they can't have done much. My clearest\r","memory is of the moment I learned it was possible for programs not\r","to terminate, when one of mine didn't. On a machine without\r","time-sharing, this was a social as well as a technical error, as\r","the data center manager's expression made clear.With microcomputers, everything changed. Now you could have a\r","computer sitting right in front of you, on a desk, that could respond\r","to your keystrokes as it was running instead of just churning through\r","a stack of punch cards and then stopping. \r","[1]The first of my friends to get a microcomputer built it himself.\r","It was sold as a kit by Heathkit. I remember vividly how impressed\r","and envious I felt watching him sitting in front of it, typing\r","programs right into the computer.Computers were expensive in those days and it took me years of\r","nagging before I convinced my father to buy one, a TRS-80, in about\r","1980. The gold standard then was the Apple II, but a TRS-80 was\r","good enough. This was when I really started programming. I wrote\r","simple games, a program to predict how high my model rockets would\r","fly, and a word processor that my father used to write at least one\r","book.
#
# There was only room in memory for about 2 pages of text, so\r","he'd write 2 pages at a time and then print them out, but it was a\r","lot better than a typewriter.Though I liked programming, I didn't plan to study it in college.\r","In college I was going to study philosophy, which sounded much more\r","powerful. It seemed, to my naive high school self, to be the study\r","of the ultimate truths, compared to which the things studied in\r","other fields would be mere domain knowledge. What I discovered when\r","I got to college was that the other fields took up so much of the\r","space of ideas that there wasn't much left for these supposed\r","ultimate truths. All that seemed left for philosophy were edge cases\r","that people in other fields felt could safely be ignored.I couldn't have put this into words when I was 18. All I knew at\r","the time was that I kept taking philosophy courses and they kept\r","being boring. So I decided to switch to AI.AI was in the air in the mid 1980s, but there were two things\r","especially that made me want to work on it: a novel by Heinlein\r","called The Moon is a Harsh Mistress, which featured an intelligent\r","computer called Mike, and a PBS documentary that showed Terry\r","Winograd using SHRDLU. I haven't tried rereading The Moon is a Harsh\r","Mistress, so I don't know how well it has aged, but when I read it\r","I was drawn entirely into its world.
#
# It seemed only a matter of\r","time before we'd have Mike, and when I saw Winograd using SHRDLU,\r","it seemed like that time would be a few years at most. All you had\r","to do was teach SHRDLU more words.There weren't any classes in AI at Cornell then, not even graduate\r","classes, so I started trying to teach myself. Which meant learning\r","Lisp, since in those days Lisp was regarded as the language of AI.\r","The commonly used programming languages then were pretty primitive,\r","and programmers' ideas correspondingly so. The default language at\r","Cornell was a Pascal-like language called PL/I, and the situation\r","was similar elsewhere. Learning Lisp expanded my concept of a program\r","so fast that it was years before I started to have a sense of where\r","the new limits were. This was more like it; this was what I had\r","expected college to do. It wasn't happening in a class, like it was\r","supposed to, but that was ok. For the next couple years I was on a\r","roll. I knew what I was going to do.For my undergraduate thesis, I reverse-engineered SHRDLU. My God\r","did I love working on that program. It was a pleasing bit of code,\r","but what made it even more exciting was my belief  hard to imagine\r","now, but not unique in 1985  that it was already climbing the\r","lower slopes of intelligence.I had gotten into a program at Cornell that didn't make you choose\r","a major."
#
#
# CONCISE SUMMARY:
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary
# We have provided an existing summary up to a certain point: The author's early interest in programming and AI led him to study computer science in college. He was particularly inspired by the works of Heinlein and Winograd, and he learned Lisp to teach himself AI. He wrote his undergraduate thesis on SHRDLU, and he believes that it was already climbing the lower slopes of intelligence.
# We have the opportunity to refine the existing summary(only if needed) with some more context below.
# ------------
# You could take whatever classes you liked, and choose\r","whatever you liked to put on your degree. I of course chose \"Artificial\r","Intelligence.\" When I got the actual physical diploma, I was dismayed\r","to find that the quotes had been included, which made them read as\r","scare-quotes. At the time this bothered me, but now it seems amusingly\r","accurate, for reasons I was about to discover.I applied to 3 grad schools: MIT and Yale, which were renowned for\r","AI at the time, and Harvard, which I'd visited because Rich Draves\r","went there, and was also home to Bill Woods, who'd invented the\r","type of parser I used in my SHRDLU clone. Only Harvard accepted me,\r","so that was where I went.I don't remember the moment it happened, or if there even was a\r","specific moment, but during the first year of grad school I realized\r","that AI, as practiced at the time, was a hoax. By which I mean the\r","sort of AI in which a program that's told \"the dog is sitting on\r","the chair\" translates this into some formal representation and adds\r","it to the list of things it knows.What these programs really showed was that there's a subset of\r","natural language that's a formal language. But a very proper subset.\r","It was clear that there was an unbridgeable gap between what they\r","could do and actually understanding natural language. It was not,\r","in fact, simply a matter of teaching SHRDLU more words.
#
# That whole\r","way of doing AI, with explicit data structures representing concepts,\r","was not going to work. Its brokenness did, as so often happens,\r","generate a lot of opportunities to write papers about various\r","band-aids that could be applied to it, but it was never going to\r","get us Mike.So I looked around to see what I could salvage from the wreckage\r","of my plans, and there was Lisp. I knew from experience that Lisp\r","was interesting for its own sake and not just for its association\r","with AI, even though that was the main reason people cared about\r","it at the time. So I decided to focus on Lisp. In fact, I decided\r","to write a book about Lisp hacking. It's scary to think how little\r","I knew about Lisp hacking when I started writing that book. But\r","there's nothing like writing a book about something to help you\r","learn it. The book, On Lisp, wasn't published till 1993, but I wrote\r","much of it in grad school.Computer Science is an uneasy alliance between two halves, theory\r","and systems. The theory people prove things, and the systems people\r","build things. I wanted to build things. I had plenty of respect for\r","theory  indeed, a sneaking suspicion that it was the more admirable\r","of the two halves  but building things seemed so much more exciting.The problem with systems work, though, was that it didn't last.\r","Any program you wrote today, no matter how good, would be obsolete\r","in a couple decades at best.
#
# People might mention your software in\r","footnotes, but no one would actually use it. And indeed, it would\r","seem very feeble work. Only people with a sense of the history of\r","the field would even realize that, in its time, it had been good.There were some surplus Xerox Dandelions floating around the computer\r","lab at one point. Anyone who wanted one to play around with could\r","have one. I was briefly tempted, but they were so slow by present\r","standards; what was the point? No one else wanted one either, so\r","off they went. That was what happened to systems work.I wanted not just to build things, but to build things that would\r","last.In this dissatisfied state I went in 1988 to visit Rich Draves at\r","CMU, where he was in grad school. One day I went to visit the\r","Carnegie Institute, where I'd spent a lot of time as a kid. While\r","looking at a painting there I realized something that might seem\r","obvious, but was a big surprise to me. There, right on the wall,\r","was something you could make that would last. Paintings didn't\r","become obsolete. Some of the best ones were hundreds of years old.And moreover this was something you could make a living doing. Not\r","as easily as you could by writing software, of course, but I thought\r","if you were really industrious and lived really cheaply, it had to\r","be possible to make enough to survive. And as an artist you could\r","be truly independent.
#
# You wouldn't have a boss, or even need to get\r","research funding.I had always liked looking at paintings. Could I make them? I had\r","no idea. I'd never imagined it was even possible. I knew intellectually\r","that people made art  that it didn't just appear spontaneously\r"," but it was as if the people who made it were a different species.\r","They either lived long ago or were mysterious geniuses doing strange\r","things in profiles in Life magazine. The idea of actually being\r","able to make art, to put that verb before that noun, seemed almost\r","miraculous.That fall I started taking art classes at Harvard. Grad students\r","could take classes in any department, and my advisor, Tom Cheatham,\r","was very easy going. If he even knew about the strange classes I\r","was taking, he never said anything.So now I was in a PhD program in computer science, yet planning to\r","be an artist, yet also genuinely in love with Lisp hacking and\r","working away at On Lisp. In other words, like many a grad student,\r","I was working energetically on multiple projects that were not my\r","thesis.I didn't see a way out of this situation. I didn't want to drop out\r","of grad school, but how else was I going to get out? I remember\r","when my friend Robert Morris got kicked out of Cornell for writing\r","the internet worm of 1988, I was envious that he'd found such a\r","spectacular way to get out of grad school.Then one day in April 1990 a crack appeared in the wall.
#
# I ran into\r","professor Cheatham and he asked if I was far enough along to graduate\r","that June. I didn't have a word of my dissertation written, but in\r","what must have been the quickest bit of thinking in my life, I\r","decided to take a shot at writing one in the 5 weeks or so that\r","remained before the deadline, reusing parts of On Lisp where I\r","could, and I was able to respond, with no perceptible delay \"Yes,\r","I think so. I'll give you something to read in a few days.\"I picked applications of continuations as the topic. In retrospect\r","I should have written about macros and embedded languages. There's\r","a whole world there that's barely been explored. But all I wanted\r","was to get out of grad school, and my rapidly written dissertation\r","sufficed, just barely.Meanwhile I was applying to art schools. I applied to two: RISD in\r","the US, and the Accademia di Belli Arti in Florence, which, because\r","it was the oldest art school, I imagined would be good. RISD accepted\r","me, and I never heard back from the Accademia, so off to Providence\r","I went.I'd applied for the BFA program at RISD, which meant in effect that\r","I had to go to college again. This was not as strange as it sounds,\r","because I was only 25, and art schools are full of people of different\r","ages. RISD counted me as a transfer sophomore and said I had to do\r","the foundation that summer.
# ------------
# Given the new context, refine the original summary
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary
# We have provided an existing summary up to a certain point: The author's early interest in programming and AI led him to study computer science in college. He was particularly inspired by the works of Heinlein and Winograd, and he learned Lisp to teach himself AI. He wrote his undergraduate thesis on SHRDLU, and he believes that it was already climbing the lower slopes of intelligence.
#
# He applied to 3 grad schools: MIT, Yale, and Harvard. Only Harvard accepted him, so that was where he went. During his first year of grad school, he realized that AI, as practiced at the time, was a hoax. He decided to focus on Lisp and write a
# We have the opportunity to refine the existing summary(only if needed) with some more context below.
# ------------
# The foundation means the classes that\r","everyone has to take in fundamental subjects like drawing, color,\r","and design.Toward the end of the summer I got a big surprise: a letter from\r","the Accademia, which had been delayed because they'd sent it to\r","Cambridge England instead of Cambridge Massachusetts, inviting me\r","to take the entrance exam in Florence that fall. This was now only\r","weeks away. My nice landlady let me leave my stuff in her attic. I\r","had some money saved from consulting work I'd done in grad school;\r","there was probably enough to last a year if I lived cheaply. Now\r","all I had to do was learn Italian.Only stranieri (foreigners) had to take this entrance exam. In\r","retrospect it may well have been a way of excluding them, because\r","there were so many stranieri attracted by the idea of studying\r","art in Florence that the Italian students would otherwise have been\r","outnumbered. I was in decent shape at painting and drawing from the\r","RISD foundation that summer, but I still don't know how I managed\r","to pass the written exam. I remember that I answered the essay\r","question by writing about Cezanne, and that I cranked up the\r","intellectual level as high as I could to make the most of my limited\r","vocabulary.
#
# \r","[2]I'm only up to age 25 and already there are such conspicuous patterns.\r","Here I was, yet again about to attend some august institution in\r","the hopes of learning about some prestigious subject, and yet again\r","about to be disappointed. The students and faculty in the painting\r","department at the Accademia were the nicest people you could imagine,\r","but they had long since arrived at an arrangement whereby the\r","students wouldn't require the faculty to teach anything, and in\r","return the faculty wouldn't require the students to learn anything.\r","And at the same time all involved would adhere outwardly to the\r","conventions of a 19th century atelier. We actually had one of those\r","little stoves, fed with kindling, that you see in 19th century\r","studio paintings, and a nude model sitting as close to it as possible\r","without getting burned. Except hardly anyone else painted her besides\r","me. The rest of the students spent their time chatting or occasionally\r","trying to imitate things they'd seen in American art magazines.Our model turned out to live just down the street from me. She made\r","a living from a combination of modelling and making fakes for a\r","local antique dealer. She'd copy an obscure old painting out of a\r","book, and then he'd take the copy and maltreat it to make it look\r","old. \r","[3]While I was a student at the Accademia I started painting still\r","lives in my bedroom at night.
#
# These paintings were tiny, because\r","the room was, and because I painted them on leftover scraps of\r","canvas, which was all I could afford at the time. Painting still\r","lives is different from painting people, because the subject, as\r","its name suggests, can't move. People can't sit for more than about\r","15 minutes at a time, and when they do they don't sit very still.\r","So the traditional m.o. for painting people is to know how to paint\r","a generic person, which you then modify to match the specific person\r","you're painting. Whereas a still life you can, if you want, copy\r","pixel by pixel from what you're seeing. You don't want to stop\r","there, of course, or you get merely photographic accuracy, and what\r","makes a still life interesting is that it's been through a head.\r","You want to emphasize the visual cues that tell you, for example,\r","that the reason the color changes suddenly at a certain point is\r","that it's the edge of an object. By subtly emphasizing such things\r","you can make paintings that are more realistic than photographs not\r","just in some metaphorical sense, but in the strict information-theoretic\r","sense. \r","[4]I liked painting still lives because I was curious about what I was\r","seeing. In everyday life, we aren't consciously aware of much we're\r","seeing.
#
# Most visual perception is handled by low-level processes\r","that merely tell your brain \"that's a water droplet\" without telling\r","you details like where the lightest and darkest points are, or\r","\"that's a bush\" without telling you the shape and position of every\r","leaf. This is a feature of brains, not a bug. In everyday life it\r","would be distracting to notice every leaf on every bush. But when\r","you have to paint something, you have to look more closely, and\r","when you do there's a lot to see. You can still be noticing new\r","things after days of trying to paint something people usually take\r","for granted, just as you can  after\r","days of trying to write an essay about something people usually\r","take for granted.This is not the only way to paint. I'm not 100% sure it's even a\r","good way to paint. But it seemed a good enough bet to be worth\r","trying.Our teacher, professor Ulivi, was a nice guy. He could see I worked\r","hard, and gave me a good grade, which he wrote down in a sort of\r","passport each student had. But the Accademia wasn't teaching me\r","anything except Italian, and my money was running out, so at the\r","end of the first year I went back to the US.I wanted to go back to RISD, but I was now broke and RISD was very\r","expensive, so I decided to get a job for a year and then return to\r","RISD the next fall. I got one at a company called Interleaf, which\r","made software for creating documents.
#
# You mean like Microsoft Word?\r","Exactly. That was how I learned that low end software tends to eat\r","high end software. But Interleaf still had a few years to live yet.\r","[5]Interleaf had done something pretty bold. Inspired by Emacs, they'd\r","added a scripting language, and even made the scripting language a\r","dialect of Lisp. Now they wanted a Lisp hacker to write things in\r","it. This was the closest thing I've had to a normal job, and I\r","hereby apologize to my boss and coworkers, because I was a bad\r","employee. Their Lisp was the thinnest icing on a giant C cake, and\r","since I didn't know C and didn't want to learn it, I never understood\r","most of the software. Plus I was terribly irresponsible. This was\r","back when a programming job meant showing up every day during certain\r","working hours. That seemed unnatural to me, and on this point the\r","rest of the world is coming around to my way of thinking, but at\r","the time it caused a lot of friction. Toward the end of the year I\r","spent much of my time surreptitiously working on On Lisp, which I\r","had by this time gotten a contract to publish.The good part was that I got paid huge amounts of money, especially\r","by art student standards. In Florence, after paying my part of the\r","rent, my budget for everything else had been $7 a day. Now I was\r","getting paid more than 4 times that every hour, even when I was\r","just sitting in a meeting.
# ------------
# Given the new context, refine the original summary
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary
# We have provided an existing summary up to a certain point: The author's early interest in programming and AI led him to study computer science in college. He was particularly inspired by the works of Heinlein and Winograd, and he learned Lisp to teach himself AI. He wrote his undergraduate thesis on SHRDLU, and he believes that it was already climbing the lower slopes of intelligence.
#
# He applied to 3 grad schools: MIT, Yale, and Harvard. Only Harvard accepted him, so that was where he went. During his first year of grad school, he realized that AI, as practiced at the time, was a hoax. He decided to focus on Lisp and write a
# We have the opportunity to refine the existing summary(only if needed) with some more context below.
# ------------
# By living cheaply I not only managed to\r","save enough to go back to RISD, but also paid off my college loans.I learned some useful things at Interleaf, though they were mostly\r","about what not to do. I learned that it's better for technology\r","companies to be run by product people than sales people (though\r","sales is a real skill and people who are good at it are really good\r","at it), that it leads to bugs when code is edited by too many people,\r","that cheap office space is no bargain if it's depressing, that\r","planned meetings are inferior to corridor conversations, that big,\r","bureaucratic customers are a dangerous source of money, and that\r","there's not much overlap between conventional office hours and the\r","optimal time for hacking, or conventional offices and the optimal\r","place for it.But the most important thing I learned, and which I used in both\r","Viaweb and Y Combinator, is that the low end eats the high end:\r","that it's good to be the \"entry level\" option, even though that\r","will be less prestigious, because if you're not, someone else will\r","be, and will squash you against the ceiling. Which in turn means\r","that prestige is a danger sign.When I left to go back to RISD the next fall, I arranged to do\r","freelance work for the group that did projects for customers, and\r","this was how I survived for the next several years.
#
# When I came\r","back to visit for a project later on, someone told me about a new\r","thing called HTML, which was, as he described it, a derivative of\r","SGML. Markup language enthusiasts were an occupational hazard at\r","Interleaf and I ignored him, but this HTML thing later became a big\r","part of my life.In the fall of 1992 I moved back to Providence to continue at RISD.\r","The foundation had merely been intro stuff, and the Accademia had\r","been a (very civilized) joke. Now I was going to see what real art\r","school was like. But alas it was more like the Accademia than not.\r","Better organized, certainly, and a lot more expensive, but it was\r","now becoming clear that art school did not bear the same relationship\r","to art that medical school bore to medicine. At least not the\r","painting department. The textile department, which my next door\r","neighbor belonged to, seemed to be pretty rigorous. No doubt\r","illustration and architecture were too. But painting was post-rigorous.\r","Painting students were supposed to express themselves, which to the\r","more worldly ones meant to try to cook up some sort of distinctive\r","signature style.A signature style is the visual equivalent of what in show business\r","is known as a \"schtick\": something that immediately identifies the\r","work as yours and no one else's. For example, when you see a painting\r","that looks like a certain kind of cartoon, you know it's by Roy\r","Lichtenstein.
#
# So if you see a big painting of this type hanging in\r","the apartment of a hedge fund manager, you know he paid millions\r","of dollars for it. That's not always why artists have a signature\r","style, but it's usually why buyers pay a lot for such work.\r","[6]There were plenty of earnest students too: kids who \"could draw\"\r","in high school, and now had come to what was supposed to be the\r","best art school in the country, to learn to draw even better. They\r","tended to be confused and demoralized by what they found at RISD,\r","but they kept going, because painting was what they did. I was not\r","one of the kids who could draw in high school, but at RISD I was\r","definitely closer to their tribe than the tribe of signature style\r","seekers.I learned a lot in the color class I took at RISD, but otherwise I\r","was basically teaching myself to paint, and I could do that for\r","free. So in 1993 I dropped out. I hung around Providence for a bit,\r","and then my college friend Nancy Parmet did me a big favor. A\r","rent-controlled apartment in a building her mother owned in New\r","York was becoming vacant. Did I want it? It wasn't much more than\r","my current place, and New York was supposed to be where the artists\r","were. So yes, I wanted it!\r","[7]Asterix comics begin by zooming in on a tiny corner of Roman Gaul\r","that turns out not to be controlled by the Romans.
#
# You can do\r","something similar on a map of New York City: if you zoom in on the\r","Upper East Side, there's a tiny corner that's not rich, or at least\r","wasn't in 1993. It's called Yorkville, and that was my new home.\r","Now I was a New York artist  in the strictly technical sense of\r","making paintings and living in New York.I was nervous about money, because I could sense that Interleaf was\r","on the way down. Freelance Lisp hacking work was very rare, and I\r","didn't want to have to program in another language, which in those\r","days would have meant C++ if I was lucky. So with my unerring nose\r","for financial opportunity, I decided to write another book on Lisp.\r","This would be a popular book, the sort of book that could be used\r","as a textbook. I imagined myself living frugally off the royalties\r","and spending all my time painting. (The painting on the cover of\r","this book, ANSI Common Lisp, is one that I painted around this\r","time. )The best thing about New York for me was the presence of Idelle and\r","Julian Weber. Idelle Weber was a painter, one of the early\r","photorealists, and I'd taken her painting class at Harvard. I've\r","never known a teacher more beloved by her students. Large numbers\r","of former students kept in touch with her, including me.
#
# After I\r","moved to New York I became her de facto studio assistant.She liked to paint on big, square canvases, 4 to 5 feet on a side.\r","One day in late 1994 as I was stretching one of these monsters there\r","was something on the radio about a famous fund manager. He wasn't\r","that much older than me, and was super rich. The thought suddenly\r","occurred to me: why don't I become rich? Then I'll be able to work\r","on whatever I want.Meanwhile I'd been hearing more and more about this new thing called\r","the World Wide Web. Robert Morris showed it to me when I visited\r","him in Cambridge, where he was now in grad school at Harvard. It\r","seemed to me that the web would be a big deal. I'd seen what graphical\r","user interfaces had done for the popularity of microcomputers. It\r","seemed like the web would do the same for the internet.If I wanted to get rich, here was the next train leaving the station.\r","I was right about that part. What I got wrong was the idea. I decided\r","we should start a company to put art galleries online. I can't\r","honestly say, after reading so many Y Combinator applications, that\r","this was the worst startup idea ever, but it was up there. Art\r","galleries didn't want to be online, and still don't, not the fancy\r","ones. That's not how they sell. I wrote some software to generate\r","web sites for galleries, and Robert wrote some to resize images and\r","set up an http server to serve the pages.
# ------------
# Given the new context, refine the original summary
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary
# We have provided an existing summary up to a certain point: The author's early interest in programming and AI led him to study computer science in college. He was particularly inspired by the works of Heinlein and Winograd, and he learned Lisp to teach himself AI. He wrote his undergraduate thesis on SHRDLU, and he believes that it was already climbing the lower slopes of intelligence.
#
# He applied to 3 grad schools: MIT, Yale, and Harvard. Only Harvard accepted him, so that was where he went. During his first year of grad school, he realized that AI, as practiced at the time, was a hoax. He decided to focus on Lisp and write a
# We have the opportunity to refine the existing summary(only if needed) with some more context below.
# ------------
# Then we tried to sign up\r","galleries. To call this a difficult sale would be an understatement.\r","It was difficult to give away. A few galleries let us make sites\r","for them for free, but none paid us.Then some online stores started to appear, and I realized that\r","except for the order buttons they were identical to the sites we'd\r","been generating for galleries. This impressive-sounding thing called\r","an \"internet storefront\" was something we already knew how to build.So in the summer of 1995, after I submitted the camera-ready copy\r","of ANSI Common Lisp to the publishers, we started trying to write\r","software to build online stores. At first this was going to be\r","normal desktop software, which in those days meant Windows software.\r","That was an alarming prospect, because neither of us knew how to\r","write Windows software or wanted to learn. We lived in the Unix\r","world. But we decided we'd at least try writing a prototype store\r","builder on Unix. Robert wrote a shopping cart, and I wrote a new\r","site generator for stores  in Lisp, of course.We were working out of Robert's apartment in Cambridge. His roommate\r","was away for big chunks of time, during which I got to sleep in his\r","room. For some reason there was no bed frame or sheets, just a\r","mattress on the floor.
#
# One morning as I was lying on this mattress\r","I had an idea that made me sit up like a capital L. What if we ran\r","the software on the server, and let users control it by clicking\r","on links? Then we'd never have to write anything to run on users'\r","computers. We could generate the sites on the same server we'd serve\r","them from. Users wouldn't need anything more than a browser.This kind of software, known as a web app, is common now, but at\r","the time it wasn't clear that it was even possible. To find out,\r","we decided to try making a version of our store builder that you\r","could control through the browser. A couple days later, on August\r","12, we had one that worked. The UI was horrible, but it proved you\r","could build a whole store through the browser, without any client\r","software or typing anything into the command line on the server.Now we felt like we were really onto something. I had visions of a\r","whole new generation of software working this way. You wouldn't\r","need versions, or ports, or any of that crap. At Interleaf there\r","had been a whole group called Release Engineering that seemed to\r","be at least as big as the group that actually wrote the software.\r","Now you could just update the software right on the server.We started a new company we called Viaweb, after the fact that our\r","software worked via the web, and we got $10,000 in seed funding\r","from Idelle's husband Julian.
#
# In return for that and doing the\r","initial legal work and giving us business advice, we gave him 10%\r","of the company. Ten years later this deal became the model for Y\r","Combinator's. We knew founders needed something like this, because\r","we'd needed it ourselves.At this stage I had a negative net worth, because the thousand\r","dollars or so I had in the bank was more than counterbalanced by\r","what I owed the government in taxes. (Had I diligently set aside\r","the proper proportion of the money I'd made consulting for Interleaf?\r","No, I had not.) So although Robert had his graduate student stipend,\r","I needed that seed funding to live on.We originally hoped to launch in September, but we got more ambitious\r","about the software as we worked on it. Eventually we managed to\r","build a WYSIWYG site builder, in the sense that as you were creating\r","pages, they looked exactly like the static ones that would be\r","generated later, except that instead of leading to static pages,\r","the links all referred to closures stored in a hash table on the\r","server.It helped to have studied art, because the main goal of an online\r","store builder is to make users look legit, and the key to looking\r","legit is high production values. If you get page layouts and fonts\r","and colors right, you can make a guy running a store out of his\r","bedroom look more legit than a big company.
#
# (If you're curious why my site looks so old-fashioned, it's because\r","it's still made with this software. It may look clunky today, but\r","in 1996 it was the last word in slick. )In September, Robert rebelled. \"We've been working on this for a\r","month,\" he said, \"and it's still not done.\" This is funny in\r","retrospect, because he would still be working on it almost 3 years\r","later. But I decided it might be prudent to recruit more programmers,\r","and I asked Robert who else in grad school with him was really good.\r","He recommended Trevor Blackwell, which surprised me at first, because\r","at that point I knew Trevor mainly for his plan to reduce everything\r","in his life to a stack of notecards, which he carried around with\r","him. But Rtm was right, as usual. Trevor turned out to be a\r","frighteningly effective hacker.It was a lot of fun working with Robert and Trevor. They're the two\r","most independent-minded people \r","I know, and in completely different\r","ways. If you could see inside Rtm's brain it would look like a\r","colonial New England church, and if you could see inside Trevor's\r","it would look like the worst excesses of Austrian Rococo.We opened for business, with 6 stores, in January 1996. It was just\r","as well we waited a few months, because although we worried we were\r","late, we were actually almost fatally early.
#
# There was a lot of\r","talk in the press then about ecommerce, but not many people actually\r","wanted online stores.\r","[8]There were three main parts to the software: the editor, which\r","people used to build sites and which I wrote, the shopping cart,\r","which Robert wrote, and the manager, which kept track of orders and\r","statistics, and which Trevor wrote. In its time, the editor was one\r","of the best general-purpose site builders. I kept the code tight\r","and didn't have to integrate with any other software except Robert's\r","and Trevor's, so it was quite fun to work on. If all I'd had to do\r","was work on this software, the next 3 years would have been the\r","easiest of my life. Unfortunately I had to do a lot more, all of\r","it stuff I was worse at than programming, and the next 3 years were\r","instead the most stressful.There were a lot of startups making ecommerce software in the second\r","half of the 90s. We were determined to be the Microsoft Word, not\r","the Interleaf. Which meant being easy to use and inexpensive. It\r","was lucky for us that we were poor, because that caused us to make\r","Viaweb even more inexpensive than we realized. We charged $100 a\r","month for a small store and $300 a month for a big one. This low\r","price was a big attraction, and a constant thorn in the sides of\r","competitors, but it wasn't because of some clever insight that we\r","set the price low.
# ------------
# Given the new context, refine the original summary
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary
# We have provided an existing summary up to a certain point: The author's early interest in programming and AI led him to study computer science in college. He was particularly inspired by the works of Heinlein and Winograd, and he learned Lisp to teach himself AI. He wrote his undergraduate thesis on SHRDLU, and he believes that it was already climbing the lower slopes of intelligence.
#
# He applied to 3 grad schools: MIT, Yale, and Harvard. Only Harvard accepted him, so that was where he went. During his first year of grad school, he realized that AI, as practiced at the time, was a hoax. He decided to focus on Lisp and write a
# We have the opportunity to refine the existing summary(only if needed) with some more context below.
# ------------
# We had no idea what businesses paid for things.\r","$300 a month seemed like a lot of money to us.We did a lot of things right by accident like that. For example,\r","we did what's now called \"doing things that \r","don't scale,\" although\r","at the time we would have described it as \"being so lame that we're\r","driven to the most desperate measures to get users.\" The most common\r","of which was building stores for them. This seemed particularly\r","humiliating, since the whole raison d'etre of our software was that\r","people could use it to make their own stores. But anything to get\r","users.We learned a lot more about retail than we wanted to know. For\r","example, that if you could only have a small image of a man's shirt\r","(and all images were small then by present standards), it was better\r","to have a closeup of the collar than a picture of the whole shirt.\r","The reason I remember learning this was that it meant I had to\r","rescan about 30 images of men's shirts. My first set of scans were\r","so beautiful too.Though this felt wrong, it was exactly the right thing to be doing.\r","Building stores for users taught us about retail, and about how it\r","felt to use our software.
#
# I was initially both mystified and repelled\r","by \"business\" and thought we needed a \"business person\" to be in\r","charge of it, but once we started to get users, I was converted,\r","in much the same way I was converted to \r","fatherhood once I had kids.\r","Whatever users wanted, I was all theirs. Maybe one day we'd have\r","so many users that I couldn't scan their images for them, but in\r","the meantime there was nothing more important to do.Another thing I didn't get at the time is that \r","growth rate is the\r","ultimate test of a startup. Our growth rate was fine. We had about\r","70 stores at the end of 1996 and about 500 at the end of 1997. I\r","mistakenly thought the thing that mattered was the absolute number\r","of users. And that is the thing that matters in the sense that\r","that's how much money you're making, and if you're not making enough,\r","you might go out of business. But in the long term the growth rate\r","takes care of the absolute number. If we'd been a startup I was\r","advising at Y Combinator, I would have said: Stop being so stressed\r","out, because you're doing fine. You're growing 7x a year. Just don't\r","hire too many more people and you'll soon be profitable, and then\r","you'll control your own destiny.Alas I hired lots more people, partly because our investors wanted\r","me to, and partly because that's what startups did during the\r","Internet Bubble. A company with just a handful of employees would\r","have seemed amateurish.
#
# So we didn't reach breakeven until about\r","when Yahoo bought us in the summer of 1998. Which in turn meant we\r","were at the mercy of investors for the entire life of the company.\r","And since both we and our investors were noobs at startups, the\r","result was a mess even by startup standards.It was a huge relief when Yahoo bought us. In principle our Viaweb\r","stock was valuable. It was a share in a business that was profitable\r","and growing rapidly. But it didn't feel very valuable to me; I had\r","no idea how to value a business, but I was all too keenly aware of\r","the near-death experiences we seemed to have every few months. Nor\r","had I changed my grad student lifestyle significantly since we\r","started. So when Yahoo bought us it felt like going from rags to\r","riches. Since we were going to California, I bought a car, a yellow\r","1998 VW GTI. I remember thinking that its leather seats alone were\r","by far the most luxurious thing I owned.The next year, from the summer of 1998 to the summer of 1999, must\r","have been the least productive of my life. I didn't realize it at\r","the time, but I was worn out from the effort and stress of running\r","Viaweb. For a while after I got to California I tried to continue\r","my usual m.o. of programming till 3 in the morning, but fatigue\r","combined with Yahoo's prematurely aged\r","culture and grim cube farm\r","in Santa Clara gradually dragged me down.
#
# After a few months it\r","felt disconcertingly like working at Interleaf.Yahoo had given us a lot of options when they bought us. At the\r","time I thought Yahoo was so overvalued that they'd never be worth\r","anything, but to my astonishment the stock went up 5x in the next\r","year. I hung on till the first chunk of options vested, then in the\r","summer of 1999 I left. It had been so long since I'd painted anything\r","that I'd half forgotten why I was doing this. My brain had been\r","entirely full of software and men's shirts for 4 years. But I had\r","done this to get rich so I could paint, I reminded myself, and now\r","I was rich, so I should go paint.When I said I was leaving, my boss at Yahoo had a long conversation\r","with me about my plans. I told him all about the kinds of pictures\r","I wanted to paint. At the time I was touched that he took such an\r","interest in me. Now I realize it was because he thought I was lying.\r","My options at that point were worth about $2 million a month. If I\r","was leaving that kind of money on the table, it could only be to\r","go and start some new startup, and if I did, I might take people\r","with me. This was the height of the Internet Bubble, and Yahoo was\r","ground zero of it. My boss was at that moment a billionaire.
#
# Leaving\r","then to start a new startup must have seemed to him an insanely,\r","and yet also plausibly, ambitious plan.But I really was quitting to paint, and I started immediately.\r","There was no time to lose. I'd already burned 4 years getting rich.\r","Now when I talk to founders who are leaving after selling their\r","companies, my advice is always the same: take a vacation. That's\r","what I should have done, just gone off somewhere and done nothing\r","for a month or two, but the idea never occurred to me.So I tried to paint, but I just didn't seem to have any energy or\r","ambition. Part of the problem was that I didn't know many people\r","in California. I'd compounded this problem by buying a house up in\r","the Santa Cruz Mountains, with a beautiful view but miles from\r","anywhere. I stuck it out for a few more months, then in desperation\r","I went back to New York, where unless you understand about rent\r","control you'll be surprised to hear I still had my apartment, sealed\r","up like a tomb of my old life. Idelle was in New York at least, and\r","there were other people trying to paint there, even though I didn't\r","know any of them.When I got back to New York I resumed my old life, except now I was\r","rich. It was as weird as it sounds. I resumed all my old patterns,\r","except now there were doors where there hadn't been.
# ------------
# Given the new context, refine the original summary
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
# > Finished chain.
# ''
